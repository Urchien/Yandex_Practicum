# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-задания" data-toc-modified-id="Описание-задания-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание задания</a></span><ul class="toc-item"><li><span><a href="#Описание-услуг" data-toc-modified-id="Описание-услуг-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание услуг</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#План-работ" data-toc-modified-id="План-работ-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>План работ</a></span></li><li><span><a href="#Техническая-часть" data-toc-modified-id="Техническая-часть-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Техническая часть</a></span></li></ul></li><li><span><a href="#Первичный-анализ-данных" data-toc-modified-id="Первичный-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Первичный анализ данных</a></span><ul class="toc-item"><li><span><a href="#Загрузим-данные-и-посмотрим-на-них" data-toc-modified-id="Загрузим-данные-и-посмотрим-на-них-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Загрузим данные и посмотрим на них</a></span></li><li><span><a href="#Опишем-каждый-датафрейм-поотдельности" data-toc-modified-id="Опишем-каждый-датафрейм-поотдельности-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Опишем каждый датафрейм поотдельности</a></span></li><li><span><a href="#Предварительный-вывод" data-toc-modified-id="Предварительный-вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Предварительный вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Объединим-наши-датафреймы" data-toc-modified-id="Объединим-наши-датафреймы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Объединим наши датафреймы</a></span></li><li><span><a href="#Приведем-данные-к-нормальному-виду" data-toc-modified-id="Приведем-данные-к-нормальному-виду-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Приведем данные к нормальному виду</a></span><ul class="toc-item"><li><span><a href="#Приведем-датафрейм-к-snake_case" data-toc-modified-id="Приведем-датафрейм-к-snake_case-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Приведем датафрейм к snake_case</a></span></li><li><span><a href="#Приведем-признак-begin_date-и-end_date-к-datetime" data-toc-modified-id="Приведем-признак-begin_date-и-end_date-к-datetime-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Приведем признак begin_date и end_date к datetime</a></span></li><li><span><a href="#Приведем-total_charges-к-float" data-toc-modified-id="Приведем-total_charges-к-float-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Приведем total_charges к float</a></span></li><li><span><a href="#Проверим,-что-получилось" data-toc-modified-id="Проверим,-что-получилось-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Проверим, что получилось</a></span></li></ul></li><li><span><a href="#Обработаем-пропущенные-значения" data-toc-modified-id="Обработаем-пропущенные-значения-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Обработаем пропущенные значения</a></span><ul class="toc-item"><li><span><a href="#Поглядим-на-пропуски:" data-toc-modified-id="Поглядим-на-пропуски:-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Поглядим на пропуски:</a></span></li><li><span><a href="#Обработаем-пропуски-в-total_charges" data-toc-modified-id="Обработаем-пропуски-в-total_charges-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Обработаем пропуски в total_charges</a></span></li><li><span><a href="#Обработаем-пропущенные-значения-у-признаков-пользователей-интернета" data-toc-modified-id="Обработаем-пропущенные-значения-у-признаков-пользователей-интернета-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Обработаем пропущенные значения у признаков пользователей интернета</a></span></li><li><span><a href="#Обработаем-пропуски-в-multiple_lines" data-toc-modified-id="Обработаем-пропуски-в-multiple_lines-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Обработаем пропуски в multiple_lines</a></span></li><li><span><a href="#Посмотрим-на-результат" data-toc-modified-id="Посмотрим-на-результат-3.3.5"><span class="toc-item-num">3.3.5&nbsp;&nbsp;</span>Посмотрим на результат</a></span></li></ul></li><li><span><a href="#Создание-новых-признаков" data-toc-modified-id="Создание-новых-признаков-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Создание новых признаков</a></span><ul class="toc-item"><li><span><a href="#Создадим-целевой-признак-'churn'" data-toc-modified-id="Создадим-целевой-признак-'churn'-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Создадим целевой признак 'churn'</a></span></li><li><span><a href="#Создадим-признак-'duration'-с-количеством-дней-пользования-договором" data-toc-modified-id="Создадим-признак-'duration'-с-количеством-дней-пользования-договором-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Создадим признак 'duration' с количеством дней пользования договором</a></span></li><li><span><a href="#Посмотрим-на-результат" data-toc-modified-id="Посмотрим-на-результат-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Посмотрим на результат</a></span></li></ul></li><li><span><a href="#Предварительный-вывод" data-toc-modified-id="Предварительный-вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Предварительный вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-распределение-категориальных-признаков" data-toc-modified-id="Посмотрим-распределение-категориальных-признаков-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрим распределение категориальных признаков</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-влияние-гендера-на-уход-клиентов" data-toc-modified-id="Посмотрим-влияние-гендера-на-уход-клиентов-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Посмотрим влияние гендера на уход клиентов</a></span></li><li><span><a href="#Посмотрим-влияние-брака-на-уход-клиентов" data-toc-modified-id="Посмотрим-влияние-брака-на-уход-клиентов-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Посмотрим влияние брака на уход клиентов</a></span></li><li><span><a href="#Посмотрим-влияние-статуса-пенсионера-на-уход-клиентов" data-toc-modified-id="Посмотрим-влияние-статуса-пенсионера-на-уход-клиентов-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Посмотрим влияние статуса пенсионера на уход клиентов</a></span></li><li><span><a href="#Посмотрим-влияние-наличия-детей-на-уход-клиентов" data-toc-modified-id="Посмотрим-влияние-наличия-детей-на-уход-клиентов-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Посмотрим влияние наличия детей на уход клиентов</a></span></li><li><span><a href="#Посмотрим-на-влияние-услуги-&quot;блокировка-опасных-сайтов&quot;-на-уход-клиентов" data-toc-modified-id="Посмотрим-на-влияние-услуги-&quot;блокировка-опасных-сайтов&quot;-на-уход-клиентов-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Посмотрим на влияние услуги "блокировка опасных сайтов" на уход клиентов</a></span></li><li><span><a href="#Посмотрим-на-влияние-услуги-&quot;облачное-хранилище-файлов&quot;-на-уход-клиентов" data-toc-modified-id="Посмотрим-на-влияние-услуги-&quot;облачное-хранилище-файлов&quot;-на-уход-клиентов-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Посмотрим на влияние услуги "облачное хранилище файлов" на уход клиентов</a></span></li><li><span><a href="#Посмотрим-на-влияние-услуги-&quot;антивирус&quot;-на-уход-клиентов" data-toc-modified-id="Посмотрим-на-влияние-услуги-&quot;антивирус&quot;-на-уход-клиентов-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Посмотрим на влияние услуги "антивирус" на уход клиентов</a></span></li><li><span><a href="#Посмотрим-на-влияние-услуги-&quot;выделенная-линия-технической-поддержки&quot;-на-уход-клиентов" data-toc-modified-id="Посмотрим-на-влияние-услуги-&quot;выделенная-линия-технической-поддержки&quot;-на-уход-клиентов-4.1.8"><span class="toc-item-num">4.1.8&nbsp;&nbsp;</span>Посмотрим на влияние услуги "выделенная линия технической поддержки" на уход клиентов</a></span></li><li><span><a href="#Посмотрим-на-влияние-услуги-&quot;стриминговое-телевидение&quot;-на-уход-клиентов" data-toc-modified-id="Посмотрим-на-влияние-услуги-&quot;стриминговое-телевидение&quot;-на-уход-клиентов-4.1.9"><span class="toc-item-num">4.1.9&nbsp;&nbsp;</span>Посмотрим на влияние услуги "стриминговое телевидение" на уход клиентов</a></span></li><li><span><a href="#Посмотрим-на-влияние-услуги-&quot;каталог-фильмов&quot;-на-уход-клиентов" data-toc-modified-id="Посмотрим-на-влияние-услуги-&quot;каталог-фильмов&quot;-на-уход-клиентов-4.1.10"><span class="toc-item-num">4.1.10&nbsp;&nbsp;</span>Посмотрим на влияние услуги "каталог фильмов" на уход клиентов</a></span></li><li><span><a href="#Посмотрим-на-влияние-услуги-&quot;подключение-телефона-к-нескольким-линиям-одновременно&quot;-на-уход-клиентов" data-toc-modified-id="Посмотрим-на-влияние-услуги-&quot;подключение-телефона-к-нескольким-линиям-одновременно&quot;-на-уход-клиентов-4.1.11"><span class="toc-item-num">4.1.11&nbsp;&nbsp;</span>Посмотрим на влияние услуги "подключение телефона к нескольким линиям одновременно" на уход клиентов</a></span></li></ul></li><li><span><a href="#Посмотрим-распределение-числовых-признаков" data-toc-modified-id="Посмотрим-распределение-числовых-признаков-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посмотрим распределение числовых признаков</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-распределение-числа-новых-пользователей-от-времени" data-toc-modified-id="Посмотрим-на-распределение-числа-новых-пользователей-от-времени-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Посмотрим на распределение числа новых пользователей от времени</a></span></li><li><span><a href="#Посмотрим-на-распределение-числа-ушедших-пользователей-от-времени" data-toc-modified-id="Посмотрим-на-распределение-числа-ушедших-пользователей-от-времени-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Посмотрим на распределение числа ушедших пользователей от времени</a></span></li><li><span><a href="#Посмотрим-на-длительность-пользования-услугами" data-toc-modified-id="Посмотрим-на-длительность-пользования-услугами-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Посмотрим на длительность пользования услугами</a></span></li><li><span><a href="#Посмотрим-на-распределение-стоимости-услуг-для-ушедших-и-оставшихся-клиентов" data-toc-modified-id="Посмотрим-на-распределение-стоимости-услуг-для-ушедших-и-оставшихся-клиентов-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Посмотрим на распределение стоимости услуг для ушедших и оставшихся клиентов</a></span></li></ul></li><li><span><a href="#Удалим-незначимые-признаки" data-toc-modified-id="Удалим-незначимые-признаки-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Удалим незначимые признаки</a></span></li><li><span><a href="#Посмотрим-корреляцию-признаков" data-toc-modified-id="Посмотрим-корреляцию-признаков-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Посмотрим корреляцию признаков</a></span></li><li><span><a href="#Предаварительный-вывод" data-toc-modified-id="Предаварительный-вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Предаварительный вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных-к-машинному-обучению" data-toc-modified-id="Подготовка-данных-к-машинному-обучению-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Подготовка данных к машинному обучению</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-баланс-классов-целевого-признака" data-toc-modified-id="Посмотрим-баланс-классов-целевого-признака-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Посмотрим баланс классов целевого признака</a></span></li><li><span><a href="#Подготовим-признаки" data-toc-modified-id="Подготовим-признаки-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Подготовим признаки</a></span></li><li><span><a href="#Разобьем-данные-на-тренировочную-и-тестовую-выборки" data-toc-modified-id="Разобьем-данные-на-тренировочную-и-тестовую-выборки-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Разобьем данные на тренировочную и тестовую выборки</a></span></li><li><span><a href="#Предварительный-вывод" data-toc-modified-id="Предварительный-вывод-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Предварительный вывод</a></span></li></ul></li><li><span><a href="#Подбор-и-обучение-моделей-машинного-обучения" data-toc-modified-id="Подбор-и-обучение-моделей-машинного-обучения-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Подбор и обучение моделей машинного обучения</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#LogisticRegression" data-toc-modified-id="LogisticRegression-6.0.1"><span class="toc-item-num">6.0.1&nbsp;&nbsp;</span>LogisticRegression</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-6.0.2"><span class="toc-item-num">6.0.2&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#CatBoostClassifier" data-toc-modified-id="CatBoostClassifier-6.0.3"><span class="toc-item-num">6.0.3&nbsp;&nbsp;</span>CatBoostClassifier</a></span></li><li><span><a href="#XGBClassifier" data-toc-modified-id="XGBClassifier-6.0.4"><span class="toc-item-num">6.0.4&nbsp;&nbsp;</span>XGBClassifier</a></span></li><li><span><a href="#Посмотим-на-сводную-таблицу:" data-toc-modified-id="Посмотим-на-сводную-таблицу:-6.0.5"><span class="toc-item-num">6.0.5&nbsp;&nbsp;</span>Посмотим на сводную таблицу:</a></span></li></ul></li><li><span><a href="#Предварительный-вывод" data-toc-modified-id="Предварительный-вывод-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Предварительный вывод</a></span></li></ul></li><li><span><a href="#Тестирование-лучшей-модели" data-toc-modified-id="Тестирование-лучшей-модели-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Тестирование лучшей модели</a></span><ul class="toc-item"><li><span><a href="#Протестируем-и-опишем-лучшую-модель" data-toc-modified-id="Протестируем-и-опишем-лучшую-модель-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Протестируем и опишем лучшую модель</a></span></li><li><span><a href="#Исследуем-важность-признаков-модели" data-toc-modified-id="Исследуем-важность-признаков-модели-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Исследуем важность признаков модели</a></span></li><li><span><a href="#Предварительный-вывод" data-toc-modified-id="Предварительный-вывод-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Предварительный вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#ОТЧЕТ" data-toc-modified-id="ОТЧЕТ-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>ОТЧЕТ</a></span><ul class="toc-item"><li><span><a href="#В-ходе-работы-над-проектом-мы-реализовывали-следующий-план:" data-toc-modified-id="В-ходе-работы-над-проектом-мы-реализовывали-следующий-план:-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>В ходе работы над проектом мы реализовывали следующий план:</a></span></li><li><span><a href="#Проанализируем-соответствие-фактической-работы-нашему-плану:" data-toc-modified-id="Проанализируем-соответствие-фактической-работы-нашему-плану:-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Проанализируем соответствие фактической работы нашему плану:</a></span></li><li><span><a href="#Проанализируем-соответствие-фактической-работы-нашему-плану:" data-toc-modified-id="Проанализируем-соответствие-фактической-работы-нашему-плану:-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Проанализируем соответствие фактической работы нашему плану:</a></span></li><li><span><a href="#Анализ-трудностей-и-путей-их-решения." data-toc-modified-id="Анализ-трудностей-и-путей-их-решения.-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Анализ трудностей и путей их решения.</a></span></li><li><span><a href="#Лучшая-модель-подобранными-с-гиперпараметрами:" data-toc-modified-id="Лучшая-модель-подобранными-с-гиперпараметрами:-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Лучшая модель подобранными с гиперпараметрами:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Исследование оттока клиентов

# %% [markdown]
# ## Описание задания
#
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# ### Описание услуг
#
# **Оператор предоставляет два основных типа услуг:**
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL, от англ. digital subscriber line, «цифровая абонентская линия») или оптоволоконный кабель (Fiber optic).
#
# **Также доступны такие услуги:**
#
# - Интернет-безопасность: антивирус (DeviceProtection) и блокировка небезопасных сайтов (OnlineSecurity);
# - Выделенная линия технической поддержки (TechSupport);
# - Облачное хранилище файлов для резервного копирования данных (OnlineBackup);
# - Стриминговое телевидение (StreamingTV) и каталог фильмов (StreamingMovies).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# ### Описание данных
#
# **Данные состоят из файлов, полученных из разных источников:**
#
# Во всех файлах столбец customerID содержит код клиента.
#
# **Датафрейм contract_new — информация о договоре**
# - customerID — ID абонента;
# - BeginDate — дата начала действия договора;
# - EndDate — дата окончания действия договора;
# - Type — тип оплаты: раз в год-два или ежемесячно;
# - PaperlessBilling — электронный расчётный лист;
# - PaymentMethod — тип платежа;
# - MonthlyCharges — расходы за месяц;
# - TotalCharges — общие расходы абонента.
#
# **Датафрейм personal_new — персональные данные клиента**
# - customerID — ID пользователя;
# - gender — пол;
# - SeniorCitizen — является ли абонент пенсионером;
# - Partner — есть ли у абонента супруг или супруга;
# - Dependents — есть ли у абонента дети.
#
# **Датафрейм internet_new — информация об интернет-услугах**
# - customerID — ID пользователя;
# - InternetService — тип подключения;
# - OnlineSecurity — блокировка опасных сайтов;
# - OnlineBackup — облачное хранилище файлов для резервного копирования данных;
# - DeviceProtection — антивирус;
# - TechSupport — выделенная линия технической поддержки;
# - StreamingTV — стриминговое телевидение;
# - StreamingMovies — каталог фильмов.
#
# **Датафрейм phone_new — информация об услугах телефонии**
# - customerID — ID пользователя;
# - MultipleLines — подключение телефона к нескольким линиям одновременно.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ### План работ
#
# 1. **Первичный анализ данных** (Загрузим данные, посмотрим на них и опишем результат)
# 2. **Предобработка данных** (Объединим все данные в один датафрейм, приведем данные к нормальному виду, при наличии избавимся от пропусков, дубликатов и аномальных значений, ну и обязательно еще чтонибудь накопаем)
# 3. **Исследовательский анализ данных** (Исследуем данные на наличие связей, посмотрим корреляцию, определимся какие признаки оставим для машинного обучения)
# 4. **Подготовка данных к машинному обучению** (Разобьем на тренировочную и тестовую выборки, подготовим признаки,  посмотрим баланс классов, определимся с метриками, и т.д.)
# 5. **Подбор и обучение моделей машинного обучения** (Выберем несколько методов ML, подберем лучшие гиперпараметры на кросс-валидации)
# 5. **Тестирование лучшей модели** (Протестируем модель показавшую лучшие метрики на тестовой выборке и сравним с константной моделью)
# 6. **Вывод** (Сделаем анализ лучшей модели, опишем важность признаков, построим матрицу ошибок. Также напишем вывод о проделаной работе)

# %% [markdown]
# ### Техническая часть
# Тут разместим импорт необходимых библиотек и объявим формулы, которые будем использовать, для улучшения визуализации проекта.

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
# Импортируем библиотеки для обработки и визуализации данных
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Импортируем библиотеки для обработки и анализа данных
import numpy as np
import re
import math

# Импортируем библиотеки для расчета корреляции
try:
    import phik
except Exception:
    # !pip install phik
    import phik
    
from phik.report import plot_correlation_matrix
from phik import report

# Импортируем библиотеки для моделирования и оценки
from sklearn.model_selection import (GridSearchCV,
                                     train_test_split,
                                     StratifiedKFold,
                                     KFold,
                                     RandomizedSearchCV)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.metrics import (roc_curve,
                             confusion_matrix,
                             roc_auc_score,
                             accuracy_score)

# Отключим предупреждения
import warnings
warnings.filterwarnings('ignore')

# Зададим random state
RANDOM_STATE = 280823

# %% [markdown]
# Объявим формулы

# %%
def data_info(dataframe):
    """
    Функция принимает на вход датафрейм, 
    а на выходе выводит все необходимые характеристики поочередно применяя методы:
    """
    # выводим первые и последние 5 строк датафрейма
    print('Выведем первые и последние 5 строк:')
    display(pd.concat([dataframe.head(), dataframe.tail()]))

    # выводим общую информацию о датафрейме
    print('\nВыведем общую информацию по датафрейму:')
    display(dataframe.info())
    
    # 
    print('\nВыведем статистическую информацию по датафрейму:')
    display(dataframe.describe(include='all').T)
    
    # выводим информацию о типах данных признаков
    print('\nПосмотрим на признаки:')
    for num, i in enumerate(dataframe.columns):
        print(
            f'{num+1}. {i} - тип данных {dataframe[i].dtype}, уникальных значений: {len(dataframe[i].unique())}')
        print(f'Список уникальных значений:\n{dataframe[i].sort_values().unique()}\n')

    # выводим информацию о пропущенных значениях
    print('\nПосмотрим пропуски:')
    display(dataframe.isnull().sum())

    # выводим количество дубликатов
    dup_count = dataframe.duplicated().sum()
    print(f'\nКоличество дубликатов: {dup_count}')

# %%
def features_vs_target_plot(dataframe, features, target):
    """
    Функция для построения графиков, отображающих распределение признаков относительно целевого признака.
    Аргументы:
    - dataframe (pandas.DataFrame): Датафрейм с данными.
    - features (list): Список признаков, для которых требуется построить графики.
    - target (str): Имя целевого признака.
    
    Визуализирует распределение каждого признака относительно целевого признака в виде столбчатых диаграмм.
    """

    # Устанавливаем целевой признак
    target = 'churn'

    # Вычисляем количество столбцов и строк для расположения графиков
    number_cols = 2
    n_rows = math.ceil(len(features) / number_cols)

    # Создаем фигуру и массив подграфиков
    fig, axes = plt.subplots(n_rows, number_cols, figsize=(16, 5 * n_rows))
    axes = axes.flatten()

    # Создаем графики для каждого признака
    for i, feature in enumerate(features):
        ax = axes[i]

        # Группируем данные по признаку и целевому признаку, считаем количество записей
        df_temp = dataframe.groupby([feature, target])[target].count().nlargest(10)
        df_temp = df_temp.unstack()

        # Строим столбчатую диаграмму для каждого значения целевого признака
        for column in df_temp.columns:
            ax.bar(df_temp.index, df_temp[column], alpha=0.4, label=column)

        # Настройка осей и легенды
        ax.set_xlabel('0 - клиент остался, 1 - клиент ушел')
        ax.set_ylabel('Количество')
        ax.legend()

        # Заголовок графика
        ax.set_title(f'Распределение признака {feature} относительно целевого признака', size=12)

    # Удаляем лишние пустые графики
    if len(features) < len(axes):
        for j in range(len(features), len(axes)):
            fig.delaxes(axes[j])

    # Располагаем графики плотно и показываем на экране
    plt.tight_layout()
    plt.show()

# %%
def numeric_hist_boxplot(dataframe, features_list):
    '''
    Функция принимает на вход датафрейм, список с числовыми признаками 
    и строит по ним гистограммы распределения и ящики с усами
    '''
    # Проходим по каждому признаку в списке
    for feature in features_list:
        # Создаем графическую область с двумя подграфиками
        fig, ax = plt.subplots(1, 2, figsize=(15, 5))

        # Строим гистограмму
        sns.histplot(dataframe[feature], bins=30, ax=ax[0])
        fig.suptitle(f'Распределение признака {feature}', size = 12)
        
        # Строим боксплот
        sns.boxplot(dataframe[feature], ax=ax[1])
        
        # Настройки подграфика гистограммы
        ax[0].set_xlabel('')
        ax[0].set_ylabel('Количество')
#         ax[0].set_title(f'Гистограмма распределения {feature}')

        # Настройки подграфика боксплота
        ax[1].set_xlabel('')
        ax[1].set_ylabel(f'{feature}')
#         ax[1].set_title(f'Боксплот {feature}')

        # Выводим графики для текущего признака
        plt.show()

# %%
def plot_user_distribution(df, feature, xlabel, ylabel, title):
    """
    Функция для отображения графика распределения.

    Аргументы:
    - df: pandas DataFrame. Датафрейм, содержащий данные.
    - feature: str. Название столбца, содержащего временной признак.
    - xlabel: str. Подпись оси x.
    - ylabel: str. Подпись оси y.
    - title: str. Название графика.
    """
    fig, ax = plt.subplots(figsize=(15, 5))
    df[feature].value_counts().plot(style='o-', grid=True, ax=ax)

    ax.set_title(title)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.minorticks_on()
    ax.grid(which='major', linewidth=.5)
    ax.grid(which='minor', linewidth=.25, linestyle='--')
    plt.show()

# %%
def kde_plot(data, xlabel='', figsize=(15, 5), label='', title='', ylabel='', legend=False, hue=None):
    """
    Функция для построения графика ядерной оценки плотности (KDE).

    Параметры:
        - data: данные для построения графика
        - xlabel: название оси x (по умолчанию пусто)
        - figsize: размеры фигуры (ширина, высота) (по умолчанию (15, 5))
        - label: название линии графика (по умолчанию пусто)
        - title: заголовок графика (по умолчанию пусто)
        - ylabel: название оси y (по умолчанию пусто)
        - legend: флаг, указывающий, нужно ли отображать легенду (по умолчанию False)
        - hue: переменная для раскраски кривых по категориальной переменной (по умолчанию None)
    """
    plt.figure(figsize=figsize)
    plt.title(title, fontsize=16)
    
    # Построение графика KDE
    sns.kdeplot(data, color='blue', alpha=0.4, shade=True, label=label, hue=hue)
    
    # Добавление сетки
    plt.grid(True, linestyle='--', linewidth=0.5)
    plt.minorticks_on()
    plt.grid(which='major', linewidth=.5)
    plt.grid(which='minor', linewidth=.25, linestyle='--')
    
    # Добавление подписей осей
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # Отображение легенды, если флаг legend установлен в True
    if legend:
        # Получение уникальных значений выбранного признака
        unique_values = data.unique()
        
        # Создание словаря для соответствия значений и лейблов
        labels = {value: f"{label} {value}" for value in unique_values}
        
        # Создание легенды с использованием словаря лейблов
        plt.legend(title=label, labels=labels)
    
    # Отображение графика
    plt.show()

# %%
def calculate_share(feature, target='churn', dataframe=pd.DataFrame()):
    """
    Функция для вычисления доли каждой категории в заданном признаке
    относительно целевого признака.

    Параметры:
        - feature: столбец с признаком, для которого вычисляются доли
        - target: столбец с целевым признаком, используемым для вычисления долей
        - dataframe: DataFrame, содержащий данные

    Возвращает:
        - table: DataFrame с вычисленными долями
    """
    table = dataframe.groupby([target, feature]).size().reset_index(name='customer_count')
    table['share_all'] = table['customer_count'] / table['customer_count'].sum()
    table['share_target'] = table.groupby(target)['customer_count'].transform(lambda x: x / x.sum())
    table[['share_target', 'share_all']] = table[['share_target', 'share_all']].round(2)
    return table

# %%
def plot_pie_chart(df, target_col, figsize=(6, 6), labeldistance=1.1, pctdistance=0.85, fontsize=12, title=''):
    """
    Функция для создания диаграммы pie на основе целевого признака в датафрейме.

    Параметры:
    - df: Pandas DataFrame с данными.
    - target_col: Строка, представляющая название целевого признака в датафрейме.
    - figsize: Кортеж, определяющий размеры диаграммы (по умолчанию: (6, 6)).
    - labeldistance: Расстояние между центром диаграммы и подписями (по умолчанию: 1.1).
    - pctdistance: Расстояние между центром диаграммы и процентными значениями (по умолчанию: 0.85).
    - fontsize: Размер шрифта для подписей (по умолчанию: 12).
    - title: Заголовок диаграммы (по умолчанию: '').

    """
    churn_counts = df[target_col].value_counts()
    labels = churn_counts.index.tolist()

    fig, ax = plt.subplots(figsize=figsize)

    pie = ax.pie(churn_counts, labels=labels, autopct='%1.1f%%', labeldistance=labeldistance, pctdistance=pctdistance)

    # Регулировка размера подписей
    for label in pie[1]:
        label.set_fontsize(fontsize)

    my_circle = plt.Circle((0, 0), 0.7, color='white')
    ax.add_artist(my_circle)

    plt.title(title)
    plt.show()

# %%
def test_model(X_train, y_train, model, param_grid, random_state=RANDOM_STATE):
    """
    Функция test_model выполняет оценку и тестирование модели машинного обучения с использованием метода 
    кросс-валидации и поиска оптимальных гиперпараметров. 
    Аргументы:
    X_train: обучающая выборка, содержащая признаки
    y_train: обучающая выборка, содержащая целевую переменную
    model: алгоритм модели машинного обучения
    random_state: random state для разбиения (по умолчанию RANDOM_STATE)
    param_grid: словарь с набором гиперпараметров для перебора во время поиска оптимальных значений.
    """
    # Создадим список числовых признаков
    num_features = X_train.select_dtypes(include=['number']).columns
       
    # Создадим список числовых признаков категориальных признаков
    cat_features = X_train.select_dtypes(include=['object']).columns

    # Создадим объект KFold для кроссвалидации
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=random_state)

    # Создание кодировщика для категориальных признаков
    preprocessor_cat = Pipeline(steps=[
        ('onehot', OneHotEncoder(handle_unknown='ignore'))
    ])

    # Создание кодировщика для числовых признаков
    preprocessor_num = Pipeline(steps=[
        ('scaler', StandardScaler())
    ])

    # Создание обработчика признаков
    preprocessor = ColumnTransformer(transformers=[
        ('categorical_encoder', preprocessor_cat, cat_features),
        ('numeric_encoder', preprocessor_num, num_features)
    ])

    # Создаем Pipeline с кодированием признаков и моделью
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('model', model)
    ])

    # Создаем объект RandomizedSearchCV для подбора гиперпараметров
    random_search = RandomizedSearchCV(pipeline, param_grid, scoring='roc_auc',
                                       cv=skf, n_jobs=-1, n_iter=50, random_state=random_state)

    # Обучаем объект RandomizedSearchCV на обучающей выборке
    random_search.fit(X_train, y_train)

    # Извлекаем лучшую модель и ее гиперпараметры
    best_model = random_search.best_estimator_
    best_params = random_search.best_params_
    best_score = random_search.best_score_
    model_name = random_search.best_estimator_.named_steps['model'].__class__.__name__

    # Выводим название модели, лучшие гиперпараметры и метрики

    result = {'Mодель': model_name,
              'Гиперпараметры': best_params,
              'ROC-AUC на трейне': round(random_search.best_score_, 2)}
    # Возвращаем лучшую модель и метрики
    return result, best_model

# %%
def evaluate_model(model, features_test):
    """
    Функция для оценки модели на тестовой выборке.

    Аргументы:
    - model: обученная модель, которую необходимо оценить
    - features_test: матрица признаков тестовой выборки

    Вывод:
    - Имя модели
    - ROC-AUC на тестовой выборке
    - Точность (Accuracy) на тестовой выборке
    - Матрица ошибок
    - ROC-кривая
    """

    # Получение имени модели
    model_name = model.named_steps['model'].__class__.__name__

    # Предсказание на тестовой выборке
    predictions = model.predict(features_test)
    probabilities = model.predict_proba(features_test)[:, 1]

    # Вычисление метрик
    roc_auc = roc_auc_score(target_test, probabilities)
    accuracy = accuracy_score(target_test, predictions)

    # Построение матрицы ошибок
    cm = confusion_matrix(target_test, predictions)

    # Вывод результатов
    print("Модель:", model_name)
    print("ROC-AUC на тестовой выборке:", round(roc_auc, 4))
    print("Точность (Accuracy) на тестовой выборке:", round(accuracy, 4))
    print('Резмер тестовой выборки:', target_test.shape)
    #print("Матрица ошибок:")
    #print(cm)

    # Создание графиков на одной строке
    fig, axes = plt.subplots(1, 2, figsize=(12, 6))

    # Построение матрицы ошибок с использованием Seaborn
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', ax=axes[0])
    axes[0].set_title(f'Матрица ошибок\n[TN, FP]\n[FN, TP]')
    axes[0].set_xlabel('Предсказанные классы')
    axes[0].set_ylabel('Реальные классы')

    # Построение ROC-кривой с использованием Seaborn
    fpr, tpr, thresholds = roc_curve(target_test, probabilities)
    sns.lineplot(fpr, tpr, label='ROC-кривая (S = {:.2f})'.format(roc_auc), ax=axes[1])
    sns.lineplot([0, 1], [0, 1], color='gray', linestyle='--', ax=axes[1])
    axes[1].set_xlabel('False Positive Rate')
    axes[1].set_ylabel('True Positive Rate')
    axes[1].set_title('ROC-Кривая')
    axes[1].legend(loc='lower right')

    # Отображение графиков
    plt.tight_layout()
    plt.show()

# %%
def plot_feature_importance(best_model):
    """
    Функция для расчета и визуализации важности признаков.

    Параметры:
    - best_model: Модель, содержащаяся в конвейере

    """

    # Получение модели из конвейера
    model = best_model.named_steps['model']

    # Проверка, поддерживает ли модель расчет важности признаков
    if hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_
        feature_names = best_model.named_steps['preprocessor'].get_feature_names_out()
        
        # Удаление названий кодировщика из начала признаков
        feature_names = [name.split("__")[1] for name in feature_names]
        
        importances_df = pd.DataFrame(importances, index=feature_names, columns=['Важность признака'])
        importances_df = importances_df.sort_values(by='Важность признака', ascending=False)
        
        # Изменение названия столбца индекса
        importances_df.index.name = 'Признак'
        
        # Построение графика важности признаков
        plt.figure(figsize=(15, 5))
        plt.title('Исследование важности признаков', fontsize=14)
        plt.bar(importances_df.index, importances_df['Важность признака'])
        plt.xticks(rotation=90)
        plt.xlabel('Признаки')
        plt.ylabel('Важность признака')
        plt.show()
        
        display(importances_df)
    else:
        print("Модель не поддерживает расчет важности признаков.")

# %% [markdown]
# ## Первичный анализ данных

# %% [markdown]
# ### Загрузим данные и посмотрим на них

# %%
try:
    contract_df = pd.read_csv('____________________________________________________contract_new.csv')
    personal_df = pd.read_csv('____________________________________________________personal_new.csv')
    internet_df = pd.read_csv('____________________________________________________internet_new.csv')
    phone_df = pd.read_csv('____________________________________________________phone_new.csv')
except:
    contract_df = pd.read_csv('____________________________________________________contract_new.csv')
    personal_df = pd.read_csv('____________________________________________________personal_new.csv')
    internet_df = pd.read_csv('____________________________________________________internet_new.csv')
    phone_df = pd.read_csv('____________________________________________________phone_new.csv')

# %%
# Объявим список со всеми датафреймами
all_df = [contract_df, personal_df, internet_df, phone_df]

# Добавим атрибут 'name' к нашим датафреймам для наглядности
contract_df.name = 'contract_df'
personal_df.name = 'personal_df'
internet_df.name = 'internet_df'
phone_df.name = 'phone_df'

# Пройдемся по списку со всеми датафреймами информационной функией
for df in all_df:
    display(f'Датафрейм {df.name}')
    data_info(df)
# Out:
# 'Датафрейм contract_df'
# Выведем первые и последние 5 строк:
#       customerID   BeginDate EndDate            Type PaperlessBilling  \
# 0     7590-VHVEG  2020-01-01      No  Month-to-month              Yes
# 1     5575-GNVDE  2017-04-01      No        One year               No
# 2     3668-QPYBK  2019-10-01      No  Month-to-month              Yes
# 3     7795-CFOCW  2016-05-01      No        One year               No
# 4     9237-HQITU  2019-09-01      No  Month-to-month              Yes
# 7038  6840-RESVB  2018-02-01      No        One year              Yes
# 7039  2234-XADUH  2014-02-01      No        One year              Yes
# 7040  4801-JZAZL  2019-03-01      No  Month-to-month              Yes
# 7041  8361-LTMKD  2019-07-01      No  Month-to-month              Yes
# 7042  3186-AJIEK  2014-08-01      No        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges
# 0              Electronic check           29.85        31.04
# ...

# %% [markdown]
# ### Опишем каждый датафрейм поотдельности
#
# **Датафрейм contract_df - информация о договоре**
#
# - В датафрейме 8 признаков и 7043 строк
# - Пропущенных значений и явных дубликатов не обнаружено
# - Заголовки стоит привести к snake_case
# - Посмотрим на признаки:
#     - customerID - id клиента, все значения уникальны, есть во всех датафреймах. По нему и будем объединять в единый датафрейм.
#     - BeginDate - дата начала пользования услугами, тип данных object - стоит перевести в datetime
#     - EndDate - дата окончания пользования услугами, тип данных object - также стоит перевести в datetime. Также встречается значение 'No' - возможно это неявный пропуск - далее разберемся.
#     - Type - тип оплаты, категориальный признак, уникальных значений: 3, чаще всего встречатеся помесячная оплата.
#     - PaperlessBilling - электронный расчётный лист - категориальный бинарный признак.
#     - PaymentMethod - тип платежа, категориальный признак, уникальных значений: 4
#     - MonthlyCharges - расходы за месяц - числовой признак, минимум 18.25, максимум 118.75, среднее 64.76 - выглядит вполне реалистично.
#     - TotalCharges - общие расходы абонента - должен быть числовым признаком, но тип данных object, поэтому переведем во float64.
#
# **Датафрейм personal_df - персональные данные клиента**
#
# - В датафрейме 5 признаков и 7043 строк
# - Пропущенных значений и явных дубликатов не обнаружено
# - Заголовки так-же стоит привести к snake_case
# - Посмотрим на признаки:
#     - customerID — ID пользователя - все по аналогии с предыдущим датафреймом.
#     - gender — пол - категориальный бинарный признак.
#     - SeniorCitizen — является ли абонент пенсионером, тип данных int64, категориальный бинарный признак.
#     - Partner — есть ли у абонента супруг или супруга - категориальный бинарный признак.
#     - Dependents — есть ли у абонента дети - категориальный бинарный признак.
#
# **Датафрейм internet_new - информация об интернет-услугах**
#
# - В датафрейме 8 признаков и 5517 строк
# - Пропущенных значений и явных дубликатов не обнаружено
# - Заголовки так-же стоит привести к snake_case
# - Посмотрим на признаки:
#     - customerID — ID пользователя - все по аналогии с предыдущими датафреймами.
#     - InternetService — тип подключения - категориальный бинарный признак.
#     - OnlineSecurity — блокировка опасных сайтов - категориальный бинарный признак.
#     - OnlineBackup — облачное хранилище файлов для резервного копирования данных - категориальный бинарный признак.
#     - DeviceProtection — антивирус - категориальный бинарный признак.
#     - TechSupport — выделенная линия технической поддержки - категориальный бинарный признак.
#     - StreamingTV — стриминговое телевидение - категориальный бинарный признак.
#     - StreamingMovies — каталог фильмов - категориальный бинарный признак.
#
# **Датафрейм phone_new — информация об услугах телефонии**
#
# - В датафрейме 2 признака и 6361 строк
# - Пропущенных значений и явных дубликатов не обнаружено
# - Заголовки так-же стоит привести к snake_case
# - Посмотрим на признаки:
#     - customerID — ID пользователя - все по аналогии с предыдущими датафреймами.
#     - подключение телефона к нескольким линиям одновременно - категориальный бинарный признак.

# %% [markdown]
# ### Предварительный вывод
#
# Мы подробно посмотрели все четрыре датафрейма и можем сделать следующие выводы:
# - Всего у нас получается 7043 пользователя, 5517 из которых пользуются интернетом и 6361 телефонией.
# - Заголовки будем приводить к snake_case
# - Не все признаки соответвуют типам своих данных (BeginDate и EndDate в contract_df будем переводить в формат datetime, TotalCharges во float)
# - Признак EndDate в contract_df содержит значение 'No', с которым надо разобраться.
# - В большинстве, все представленные в датафреймах признаки - категориальные.
# - Целевой признак не обнаружен, будем его выделять из имеющихся в наличии.
#
# **Осмотр данных окончен. Приступим к предобраотке**

# %% [markdown]
# ## Предобработка данных
#
# В этом разделе мы:
# - Объединим 4 датафрейма в один
# - Приведем данные к нормальному виду
# - Обработаем пропущенные значения
# - Выделим целевой признак для машинного обучения и при необходимости создадим/удалим признаки

# %% [markdown]
# ### Объединим наши датафреймы

# %%
full_df = contract_df.merge(personal_df, how='left', on='customerID').merge(
    internet_df, how='left', on='customerID').merge(phone_df, how='left', on='customerID').set_index('customerID')
# Проверим объединение
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   object
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  InternetService   5517 non-null   object
#  12  OnlineSecurity    5517 non-null   object
#  13  OnlineBackup      5517 non-null   object
#  14  DeviceProtection  5517 non-null   object
#  15  TechSupport       5517 non-null   object
# ...

# %% [markdown]
# ### Приведем данные к нормальному виду

# %% [markdown]
# #### Приведем датафрейм к snake_case

# %%
full_df.columns = [re.sub(r'(?<!^)(?=[A-Z])', '_', i).lower()
                   for i in full_df.columns]
full_df = full_df.applymap(lambda x: x.lower() if isinstance(
    x, str) and not pd.isna(x) else x)

# Красоты ради исправим имя одного признака
full_df = full_df.rename(columns={'streaming_t_v': 'streaming_tv'})

# Проверим
full_df.head()
# Out:
#             begin_date end_date            type paperless_billing  \
# customerID
# 7590-VHVEG  2020-01-01       no  month-to-month               yes
# 5575-GNVDE  2017-04-01       no        one year                no
# 3668-QPYBK  2019-10-01       no  month-to-month               yes
# 7795-CFOCW  2016-05-01       no        one year                no
# 9237-HQITU  2019-09-01       no  month-to-month               yes
#
#                        payment_method  monthly_charges total_charges  gender  \
# customerID
# 7590-VHVEG           electronic check            29.85         31.04  female
# 5575-GNVDE               mailed check            56.95       2071.84    male
# 3668-QPYBK               mailed check            53.85        226.17    male
# 7795-CFOCW  bank transfer (automatic)            42.30        1960.6    male
# 9237-HQITU           electronic check            70.70         353.5  female
#
#             senior_citizen partner dependents internet_service  \
# customerID
# ...

# %% [markdown]
# Красота! Индексы трогать не станем)

# %% [markdown]
# #### Приведем признак begin_date и end_date к datetime
#
# В признаке end_date присутсвуют значения 'no'. Можем предположить, что пользователи на момент снятия базы пользуются услугами компании. Заменим это значение на дату снятия базы - в будущем это поможет формированию целевого и дополнительных признаков.

# %%
# Приведем begin_date к datetime
full_df['begin_date'] = pd.to_datetime(full_df['begin_date'], format='%Y-%m-%d %H:%M:%S')
# Заменим no в столбце EndDate на дату выгрузки данных '2020-02-01'.
full_df.loc[full_df['end_date'] == 'no', 'end_date'] = '2020-02-01'
# Приведем end_date к datetime
full_df['end_date'] = pd.to_datetime(full_df['end_date'], format='%Y-%m-%d')

# %% [markdown]
# #### Приведем total_charges к float

# %%
full_df['total_charges'] = pd.to_numeric(full_df['total_charges'], errors='coerce')

# %% [markdown]
# #### Проверим, что получилось

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   begin_date         7043 non-null   datetime64[ns]
#  1   end_date           7043 non-null   datetime64[ns]
#  2   type               7043 non-null   object
#  3   paperless_billing  7043 non-null   object
#  4   payment_method     7043 non-null   object
#  5   monthly_charges    7043 non-null   float64
#  6   total_charges      7032 non-null   float64
#  7   gender             7043 non-null   object
#  8   senior_citizen     7043 non-null   int64
#  9   partner            7043 non-null   object
#  10  dependents         7043 non-null   object
#  11  internet_service   5517 non-null   object
#  12  online_security    5517 non-null   object
#  13  online_backup      5517 non-null   object
#  14  device_protection  5517 non-null   object
# ...

# %% [markdown]
# Из таблички мы можем увидеть, что не заметили при первичном анализе 11 пропусков в total_charges. В остально все выглядит красиво. Займемся пропущенными значениями.

# %% [markdown]
# ### Обработаем пропущенные значения

# %% [markdown]
# #### Поглядим на пропуски:

# %%
full_df.isna().sum()
# Out:
# begin_date              0
# end_date                0
# type                    0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges          11
# gender                  0
# senior_citizen          0
# partner                 0
# dependents              0
# internet_service     1526
# online_security      1526
# online_backup        1526
# device_protection    1526
# tech_support         1526
# streaming_tv         1526
# streaming_movies     1526
# multiple_lines        682
# dtype: int64

# %% [markdown]
# Итак мы имеем:
# - 11 свеженайденных пропусков в total_charges
# - 1526 пропусков во всех признаках пользователей интернета. Все признаки категориальные, бинарные.
# - 682 пропуска в признаке multiple_lines. Признак также категориальный бинарный.

# %% [markdown]
# #### Обработаем пропуски в total_charges
#
# Посмотрим на них:

# %%
full_df[full_df['total_charges'].isnull()]
# Out:
#            begin_date   end_date      type paperless_billing  \
# customerID
# 4472-LVYGI 2020-02-01 2020-02-01  two year               yes
# 3115-CZMZD 2020-02-01 2020-02-01  two year                no
# 5709-LVOEQ 2020-02-01 2020-02-01  two year                no
# 4367-NUYAO 2020-02-01 2020-02-01  two year                no
# 1371-DWPAZ 2020-02-01 2020-02-01  two year                no
# 7644-OMVMY 2020-02-01 2020-02-01  two year                no
# 3213-VVOLG 2020-02-01 2020-02-01  two year                no
# 2520-SGTTA 2020-02-01 2020-02-01  two year                no
# 2923-ARZLG 2020-02-01 2020-02-01  one year               yes
# 4075-WKNIU 2020-02-01 2020-02-01  two year                no
# 2775-SEFEE 2020-02-01 2020-02-01  two year               yes
#
#                        payment_method  monthly_charges  total_charges  gender  \
# customerID
# 4472-LVYGI  bank transfer (automatic)            52.55            NaN  female
# ...

# %% [markdown]
# Как мы видим из таблицы - все пропуски с датой начала действия договора 2020-02-01. Соответвенно можем предположить, что пользователи заключили договор в момент снятия базы и общие расходы абонента равны месячному платежу. Поэтому заменим пропуски на значения из monthly_charges.

# %%
full_df['total_charges'].fillna(full_df['monthly_charges'], inplace=True)
# Проверим
full_df['total_charges'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Обработаем пропущенные значения у признаков пользователей интернета
#
# Количество пропусках в признаках пользователей интернета и дополнительных услуг('internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies') идентично: по 1526 штук. Мы можем предположить, что эти пользователи не пользуются интернетом компании и как следствие не нуждаются в дополнительных услугах. Поэтому заменим пропущенные значения в этих признаках на 'no'

# %%
columns_to_fill = ['internet_service', 'online_security', 'online_backup',
                   'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies']
full_df[columns_to_fill] = full_df[columns_to_fill].fillna('no')

# Проверим
print(full_df[columns_to_fill].isna().sum())
# Out:
# internet_service     0
# online_security      0
# online_backup        0
# device_protection    0
# tech_support         0
# streaming_tv         0
# streaming_movies     0
# dtype: int64

# %% [markdown]
# #### Обработаем пропуски в multiple_lines
#
# Признак multiple_lines (подключение телефона к нескольким линиям одновременно), также как и признаки пользователей интернета: категориальный, бинарный. Мы можем предположить, что наличие пропусков в этом признаке, это отсутствие подключения к телефонным линиям компании. Заменим пропуски на 'not_connected'.

# %%
full_df['multiple_lines'] = full_df['multiple_lines'].fillna('not_connected')

# Проверим
full_df['multiple_lines'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Посмотрим на результат

# %%
full_df.isna().sum()
# Out:
# begin_date           0
# end_date             0
# type                 0
# paperless_billing    0
# payment_method       0
# monthly_charges      0
# total_charges        0
# gender               0
# senior_citizen       0
# partner              0
# dependents           0
# internet_service     0
# online_security      0
# online_backup        0
# device_protection    0
# tech_support         0
# streaming_tv         0
# streaming_movies     0
# multiple_lines       0
# dtype: int64

# %% [markdown]
# **Пропущенные значения обработаны.** Приступим к выделению целевого признака и созданию новых признаков

# %% [markdown]
# ### Создание новых признаков

# %% [markdown]
# #### Создадим целевой признак 'churn'
#
# Создаем категориальный бинарный признак: если пользователь на момент снятия данных перестал пользоваться услугами компании - значение признака будет 1, если остался - значение 0.

# %%
full_df['churn'] = np.where(full_df['end_date'] < '2020-02-01', 1, 0)

# %% [markdown]
# #### Создадим признак 'duration' с количеством дней пользования договором

# %%
full_df['duration'] = (full_df.end_date - full_df.begin_date).dt.days

# %% [markdown]
# #### Посмотрим на результат

# %%
display(full_df.sample(5))
for num, i in enumerate(full_df.columns):
    print(
        f'{num+1}. {i} - количество строк: {len(full_df[i])}, тип данных: {full_df[i].dtype}, ' 
        f'уникальных значений: {len(full_df[i].unique())}'
    )
# Out:
#            begin_date   end_date            type paperless_billing  \
# customerID
# 3452-FLHYD 2018-01-01 2019-10-01        one year               yes
# 7299-GNVPL 2018-03-01 2020-02-01  month-to-month                no
# 8380-MQINP 2015-07-01 2020-02-01        two year                no
# 0484-JPBRU 2016-09-01 2020-02-01  month-to-month               yes
# 3780-DDGSE 2017-03-01 2020-02-01  month-to-month               yes
#
#                        payment_method  monthly_charges  total_charges  gender  \
# customerID
# 3452-FLHYD  bank transfer (automatic)            20.95         439.95    male
# 7299-GNVPL               mailed check            84.40        1941.20  female
# 8380-MQINP               mailed check            20.30        1116.50  female
# 0484-JPBRU  bank transfer (automatic)            25.25        1107.72    male
# 3780-DDGSE           electronic check            76.05        2661.75    male
#
# ...

# %% [markdown]
# ### Предварительный вывод
#
# В этом разделе мы:
# - Объединили 4 исходные датафрейма в один
# - Привели заголовки признаков к snake_case, а значения категориальных признаков к нижнему регистру
# - Привели признаки с датами 'begin_date' и 'end_date' к datetime
# - Заполнили пропущенные значения в признаках услуг интернета, телефонии и допуслуг.
# - Выделили целевой признак 'churn' для машинного обучения
# - Добавили признак  'duration' с количеством дней пользования договором.
# - Удалять незначимые для машинного обучения признаки будем после исследовательского анализа.
#
# **Предобработка данных завершена. Приступаем к исследовательскому анализу данных.**

# %% [markdown]
# ## Исследовательский анализ данных
#
# В этом разделе мы:
#
# - Посмотрим распределение признаков
# - Посмотрим корреляцию
# - Определимся какие признаки оставим для машинного обучения

# %% [markdown]
# ### Посмотрим распределение категориальных признаков

# %%
# Создаем список категориальных признаков
cat_features = list(full_df.select_dtypes(include=['object']).columns)
    
# В качестве 'костыля' вручную добавим к списку категориальный признак с типом данных 'int'
cat_features.append('senior_citizen')

# Выводим графики
features_vs_target_plot(full_df, cat_features, 'churn')

# %% [markdown]
# Из гистограмм распределения мы можем предположить:
# - **'type'** - Тип оплаты услуг (раз в год-два или ежемесячно). Врядли влияет на отток клиентов. Среди типов оплаты преобладает помесячная оплата и у нее меньшая доля оттока клиентов. Заплативших за 2 года обслуживания немного меньше, чем заплативших за год.
# - **'paperless_billing'** - Расчетный лист на бумаге предпочитают получать меньше клиентов, чем электонный расчетный лист. Большинство ушедших клиентов получали электронные счета, но это врядли связано с причиной ухода - скорее всего это показатель вовлеченности клиентов в электронные способы оплаты услуг. Бумажные документы как правило предпочитают люди преклонного возраста.
# - **'payment_method'** - Клиенты предпочитают электонный платеж, расчетам по почте, банковским переводам и оплате картой. Ушедшие клиенты меньше всего использовали расчеты по почте.
# - **'gender'** - Мужчины и женщины распределены примерно поровну. Аналогично распределены и ушедшие клиенты. Влияние гендера на отток клиентов рассмотрим ниже.
# - **'partner'** - Клиентов состоящих в браке чуть меньше, чем не состоящих. Чаще уходят клиенты состоящие в браке. Влияние брака на отток клиентов рассмотрим ниже.
# - **'dependents'** - Клиентов без детей более, чем в 2 раза больше, чем клиентов с детьми. Уходят чаще клиенты без детей. Влияние наличия детей на отток клиентов рассмотрим ниже.
# - **'internet_service'** - Клиенты отдают предпочтение оптоволоконному подключению. Ушедшие клиенты распределены в равных пропорциях. Влияние на уход клиентов малозначительно.
# - **'online_security'** - Большинство клиентов не используют услугу блокировка опасных сайтов. Ушедших клиентов не использующих услугу немного больше. Подробно влияние этого фактора на уход рассмотрим ниже.
# - **'online_backup'** - Большинство клиентов не используют услугу облачное хранилище файлов для резервного копирования данных. Количество ушедших клиентов примерное такое-же, как оставшихся. Подробно влияние этого фактора на уход рассмотрим ниже.
# - **'device_protection'** - Большинство клиентов не используют услугу антивирус. Количество ушедших клиентов примерное такое-же, как оставшихся. Подробно влияние этого фактора на уход рассмотрим ниже.
# - **'tech_support'** - Большинство клиентов не используют услугу выделенная линия технической поддержки. Ушедших клиентов не использующих услугу немного больше. Подробно влияние этого фактора на уход рассмотрим ниже.
# - **'streaming_tv'** - Большинство клиентов не используют услугу стриминговое телевидение. Количество ушедших клиентов примерное такое-же, как оставшихся. Подробно влияние этого фактора на уход рассмотрим ниже.
# - **'streaming_movies'** - Большинство клиентов не используют услугу каталог фильмов. Ушедших клиентов не использующих услугу немного больше. Подробно влияние этого фактора на уход рассмотрим ниже.
# - **'multiple_lines'** - Большинство клиентов не используют услугу подключение телефона к нескольким линиям одновременно. Ушедшие клиенты распределены пропорционально. Подробно влияние этого фактора на уход рассмотрим ниже.
# - **'senior_citizen'** -  Клиентов пенсионеров практически в 6 раз меньше. Ушедшие клиенты распределены пропорционально. Подробно влияние этого фактора на уход рассмотрим ниже.

# %% [markdown]
# #### Посмотрим влияние гендера на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние гендера на уход клиентов', hue=full_df['gender'])

# %% [markdown]
# Из графика мы можем видеть, что гендер не влияет на уход клиентов

# %% [markdown]
# #### Посмотрим влияние брака на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние брака клиента на уход', hue=full_df['partner'])

# %% [markdown]
# Из графика мы можем видеть, что большинство ушедших клиентов находятся в браке.

# %% [markdown]
# #### Посмотрим влияние статуса пенсионера на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние статуса пенсионера на уход клиента', hue=full_df['senior_citizen'])

# %% [markdown]
# Из графика мы можем видеть, что что большинство ушедших клиентов не имеют статуса пенсионера.

# %% [markdown]
# #### Посмотрим влияние наличия детей на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние наличия детей на уход клиента', hue=full_df['dependents'])

# %% [markdown]
# Из графика мы можем видеть, что что большинство ушедших клиентов детей не имеют.

# %% [markdown]
# #### Посмотрим на влияние услуги "блокировка опасных сайтов" на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние услуги "блокировка опасных сайтов" на уход клиента', 
         hue=full_df['online_security'])

# %%
calculate_share('online_security', dataframe=full_df)
# Out:
#    churn online_security  customer_count  share_all  share_target
# 0      0              no            4338       0.62          0.73
# 1      0             yes            1604       0.23          0.27
# 2      1              no             686       0.10          0.62
# 3      1             yes             415       0.06          0.38

# %% [markdown]
# Исходя из графика и сводной таблицы мы можем предположить, что влияние услуги "блокировка опасных сайтов" на уход клиентов малозначительно.

# %% [markdown]
# #### Посмотрим на влияние услуги "облачное хранилище файлов" на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние услуги "облачное хранилище файлов" на уход клиента', 
         hue=full_df['online_backup'])

# %%
calculate_share('online_backup', dataframe=full_df)
# Out:
#    churn online_backup  customer_count  share_all  share_target
# 0      0            no            4073       0.58          0.69
# 1      0           yes            1869       0.27          0.31
# 2      1            no             541       0.08          0.49
# 3      1           yes             560       0.08          0.51

# %% [markdown]
# Исходя из графика и сводной таблицы мы можем предположить, что влияние услуги "облачное хранилище файлов" на уход клиентов малозначительно.

# %% [markdown]
# #### Посмотрим на влияние услуги "антивирус" на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние услуги "антивирус" на уход клиента', 
         hue=full_df['device_protection'])

# %%
calculate_share('device_protection', dataframe=full_df)
# Out:
#    churn device_protection  customer_count  share_all  share_target
# 0      0                no            4070       0.58          0.68
# 1      0               yes            1872       0.27          0.32
# 2      1                no             551       0.08          0.50
# 3      1               yes             550       0.08          0.50

# %% [markdown]
# Исходя из графика и сводной таблицы мы можем предположить, что влияние услуги "антивирус" на уход клиентов малозначительно.

# %% [markdown]
# #### Посмотрим на влияние услуги "выделенная линия технической поддержки" на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние услуги "выделенная линия технической поддержки" на уход клиента', 
         hue=full_df['tech_support'])

# %%
calculate_share('tech_support', dataframe=full_df)
# Out:
#    churn tech_support  customer_count  share_all  share_target
# 0      0           no            4296       0.61          0.72
# 1      0          yes            1646       0.23          0.28
# 2      1           no             703       0.10          0.64
# 3      1          yes             398       0.06          0.36

# %% [markdown]
# Исходя из графика и сводной таблицы мы можем предположить, что влияние услуги "выделенная линия технической поддержки" на уход клиентов малозначительно.

# %% [markdown]
# #### Посмотрим на влияние услуги "стриминговое телевидение" на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние услуги "стриминговое телевидение" на уход клиента', 
         hue=full_df['streaming_tv'])

# %%
calculate_share('streaming_tv', dataframe=full_df)
# Out:
#    churn streaming_tv  customer_count  share_all  share_target
# 0      0           no            3819       0.54          0.64
# 1      0          yes            2123       0.30          0.36
# 2      1           no             517       0.07          0.47
# 3      1          yes             584       0.08          0.53

# %% [markdown]
# Исходя из графика и сводной таблицы мы можем предположить, что влияние услуги "стриминговое телевидение" на уход клиентов малозначительно.

# %% [markdown]
# #### Посмотрим на влияние услуги "каталог фильмов" на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние услуги "каталог фильмов" на уход клиента', 
         hue=full_df['streaming_movies'])

# %%
calculate_share('streaming_movies', dataframe=full_df)
# Out:
#    churn streaming_movies  customer_count  share_all  share_target
# 0      0               no            3816       0.54          0.64
# 1      0              yes            2126       0.30          0.36
# 2      1               no             495       0.07          0.45
# 3      1              yes             606       0.09          0.55

# %% [markdown]
# Исходя из графика и сводной таблицы мы можем предположить, что влияние услуги "каталог фильмов" на уход клиентов малозначительно.

# %% [markdown]
# #### Посмотрим на влияние услуги "подключение телефона к нескольким линиям одновременно" на уход клиентов

# %%
kde_plot(full_df['churn'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), title='Влияние услуги "подключение телефона к нескольким линиям одновременно" на уход клиента', 
         hue=full_df['multiple_lines'])

# %%
calculate_share('multiple_lines', dataframe=full_df)
# Out:
#    churn multiple_lines  customer_count  share_all  share_target
# 0      0             no            3070       0.44          0.52
# 1      0  not_connected             579       0.08          0.10
# 2      0            yes            2293       0.33          0.39
# 3      1             no             320       0.05          0.29
# 4      1  not_connected             103       0.01          0.09
# 5      1            yes             678       0.10          0.62

# %% [markdown]
# Исходя из графика и сводной таблицы мы можем предположить, что влияние услуги "подключение телефона к нескольким линиям одновременно" на уход клиентов малозначительно.

# %% [markdown]
# **По результам анализа категориальных признаков, мы пришли к выводу:**
# - Признак **'gender'** на уход не влияет - будем удалять.
# - Большинство ушедших клиентов не имеют пенсионного статуса, чаще всего в состоят браке и преобладают клиенты без детей.
# - Влияние на уход клиента  типа подключения к интернету - малозначительно, т.к. ушедшие клиенты распределены в равных пропорциях.
# - Влияние на уход клиента дополнительных услуг (**'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_tv', 'streaming_movies', 'multiple_lines'**) - малозначительно, в связи с небольшим числом пользователей.

# %% [markdown]
# ### Посмотрим распределение числовых признаков

# %%
# Создаем список числовых признаков (в этот раз вручную)
num_features = ['monthly_charges', 'total_charges', 'duration']
# Выводим графики
display(full_df[['monthly_charges', 'total_charges', 'duration']].describe())
numeric_hist_boxplot(full_df, num_features)
# Out:
#        monthly_charges  total_charges     duration
# count      7043.000000    7043.000000  7043.000000
# mean         64.761692    2115.377573   898.555729
# std          30.090047    2112.678861   683.130510
# min          18.250000      19.050000     0.000000
# 25%          35.500000     436.750000   276.000000
# 50%          70.350000    1343.350000   761.000000
# 75%          89.850000    3236.690000  1461.000000
# max         118.750000    9221.380000  2314.000000

# %% [markdown]
# Из гистограмм распределения и ящиков с усами мы можем сделать вывод, что во всех трех признаках:
# - Отстутвуют аномальные значения.
# - Имеются высокие пики в районе нуля. Можем предположить, что это связано с появлением новых пользователей и как следствие пика нулевых показателей.

# %% [markdown]
# #### Посмотрим на распределение числа новых пользователей от времени

# %%
plot_user_distribution(full_df, 'begin_date', 'Дата подключения', 'количество пользователей',
                       'График распределения числа новых пользователей от времени')

# %%
full_df['begin_date'].value_counts().describe()
# Out:
# count     77.000000
# mean      91.467532
# std       58.409531
# min        2.000000
# 25%       65.000000
# 50%       75.000000
# 75%       98.000000
# max      366.000000
# Name: begin_date, dtype: float64

# %% [markdown]
# Из графика распределения числа новых пользователей от времени мы можем сделать наблюдать:
#
# - В период с начала 2014 года произошел резкий рост числа новых клиентов компании. Вероятно, это связано с проведением промо-акций, которые помогли привлечь внимание к компании и начать пользоваться ее услугами на выгодных условиях. Этот период активных промо-акций длился около четверти года. После этого число новых клиентов начало снижаться.
#
# - Со 2-й четверти 2014 года по середину 2019 года мы наблюдали плавный рост числа новых клиентов, примерно на уровне 75 клиентов в месяц.
#
# - С середины 2019 года по январь 2020 года произошло заметное увеличение ежемесячного прироста пользователей, примерно в 3 раза. Это свидетельствует о, возможно, проведенных новых акциях, которые были запущены в ответ на начавшийся отток клиентов.
#
# - График по данным за февраль 2020 года представлен только за 1 день, так как данные были выгружены на момент 1 февраля 2020 года. В этот день мы наблюдаем резкое уменьшение числа вновь зарегистрированных пользователей.

# %% [markdown]
# #### Посмотрим на распределение числа ушедших пользователей от времени

# %%
filtered_df = full_df[full_df['end_date'] < '2020-02-01']
plot_user_distribution(filtered_df, 'end_date', 'Дата расторжения договора', 'количество пользователей',
                       'График распределения числа ушедших пользователей от времени')

# %% [markdown]
# Из графика распределения числа ушедших пользователей от времени мы можем сделать наблюдать:
#
# - Начиная с 2015 года рост количества ушедших пользователей компании.
# - Пиковые значения по уходу пользователей приходятся на следующие периоды: конец 2014 года, начало 4 квартала 2015 года, середина 2016 года, середина 4 квартала 2017 года, середина 4 квартала 2018 года и конец 4 квартала 2019 года.
#
# Рассмотрим ушедших клиентов по подробнее.

# %% [markdown]
# #### Посмотрим на длительность пользования услугами

# %%
kde_plot(full_df.loc[full_df['churn'] == 1, 'duration'], xlabel='Длительность пользования услугами в днях',
         ylabel='Плотность распределения', figsize=(15, 5), title='Распределение длительности пользования услугами')

# %%
full_df['duration'].describe()
# Out:
# count    7043.000000
# mean      898.555729
# std       683.130510
# min         0.000000
# 25%       276.000000
# 50%       761.000000
# 75%      1461.000000
# max      2314.000000
# Name: duration, dtype: float64

# %% [markdown]
# На графике мы можем наблюдать:
# - Количество дней пользования услуг от 0 до 2314 дней.
# - Большинство клиентов уходит в диапазоне от 500 до 1500 дней.
# - В среднем клиент пользуется услугами 898 дня, это примерно 2.5 года.

# %% [markdown]
# #### Посмотрим на распределение стоимости услуг для ушедших и оставшихся клиентов

# %%
kde_plot(full_df['monthly_charges'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), label='0', title='Распределение величины расходов за месяц', hue=full_df['churn'])

# %%
kde_plot(full_df['total_charges'], xlabel='0 - клиент остался, 1 - клиент ушел', ylabel='Плотность распределения',
         figsize=(15, 5), label='0', title='Распределение величины общих расходов', hue=full_df['churn'])

# %%
full_df.groupby('churn')['monthly_charges', 'total_charges', 'duration'].median()
# Out:
#        monthly_charges  total_charges  duration
# churn
# 0                 69.2        1192.80     702.0
# 1                 84.2        2139.03     915.0

# %% [markdown]
# Из графиков и сводной таблички мы можем увидеть:
# - Уходящие клиенты платят больше.
# - Расходы за месяц у ушедших клиентов в районе 100 у.е., тогда как подключенные клиенты платят в около 80 у.е. в месяц. Пик в начале графика расходов за месяц мы можем объяснить промокомпанией на в начале 2014 года.
# - Общие расходы у ушедших клиентов в в диапазоне от 500 до 2000 у.е., а у подключенных клиентов в районе 500 у.е.
# - Медианные данные в сводной табличке подтверждают наши выводы.

# %% [markdown]
# ### Удалим незначимые признаки
#
# - Признаки **'begin_date' и 'end_date'** после исследовательского анализа нам больше не нужны -удалим их.
# - Также исследовательский аназиз выявил, что признак **'gender'** не влияет на уход клиента - удалим его.

# %%
full_df = full_df.drop(['begin_date', 'end_date', 'gender'], axis=1)

# %% [markdown]
# ### Посмотрим корреляцию признаков

# %% [markdown]
# Посмосмотрим на данные

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7043 non-null   object
#  1   paperless_billing  7043 non-null   object
#  2   payment_method     7043 non-null   object
#  3   monthly_charges    7043 non-null   float64
#  4   total_charges      7043 non-null   float64
#  5   senior_citizen     7043 non-null   int64
#  6   partner            7043 non-null   object
#  7   dependents         7043 non-null   object
#  8   internet_service   7043 non-null   object
#  9   online_security    7043 non-null   object
#  10  online_backup      7043 non-null   object
#  11  device_protection  7043 non-null   object
#  12  tech_support       7043 non-null   object
#  13  streaming_tv       7043 non-null   object
#  14  streaming_movies   7043 non-null   object
# ...

# %% [markdown]
# Посмотрим корреляцию Phik для признаков и с ее помощью выявим наличие мультиколеарности и отберем признаки для машинного обучения.

# %%
phik_corr_matrix = full_df.phik_matrix()
phik_corr_matrix.round(2)
# Out:
# interval columns not set, guessing: ['monthly_charges', 'total_charges', 'senior_citizen', 'churn', 'duration']
#                    type  paperless_billing  payment_method  monthly_charges  \
# type               1.00               0.11            0.28             0.39
# paperless_billing  0.11               1.00            0.37             0.47
# payment_method     0.28               0.37            1.00             0.40
# monthly_charges    0.39               0.47            0.40             1.00
# total_charges      0.47               0.20            0.34             0.71
# senior_citizen     0.09               0.24            0.29             0.30
# partner            0.18               0.01            0.24             0.20
# dependents         0.15               0.17            0.22             0.18
# internet_service   0.51               0.23            0.32             0.92
# online_security    0.15               0.00            0.26             0.55
# ...

# %%
interval_cols = ['monthly_charges', 'total_charges', 'duration']
phik_corr_matrix = full_df.phik_matrix(interval_cols = interval_cols)

# %%
plot_correlation_matrix(phik_corr_matrix.values,
                        x_labels=phik_corr_matrix.columns,
                        y_labels=phik_corr_matrix.index,
                        vmin=0,
                        vmax=1,
                        color_map='Blues',
                        title=r'Correlation $\phi_K$',
                        fontsize_factor=1.5,
                        figsize=(15, 10))
plt.show()

# %% [markdown]
# Зададим порог корреляции - 0.8 и выделим признаки превышиющие этот порог.
#
# - total_charges и duration - 0.85
# - monthly_charges и streaming_movies - 0.83
# - monthly_charges и streaming_tv - 0.84
# - monthly_charges и internet_service - 0.92
#
# Признаки total_charges и duration показали самую высокую корреляцию. Это логично - чем дольше клиент обслуживается, тем выше общие расходы. Удалим total_charges.
# Признаки streaming_movies, streaming_tv и internet_service, показавшие высокую корреляцию, мы также удалим. Выше мы выяснили, что их влияние на отток клиентов малозначительно.

# %%
full_df = full_df.drop(['total_charges', 'streaming_movies', 'streaming_tv', 'internet_service'], axis=1)
# Проверим
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7043 non-null   object
#  1   paperless_billing  7043 non-null   object
#  2   payment_method     7043 non-null   object
#  3   monthly_charges    7043 non-null   float64
#  4   senior_citizen     7043 non-null   int64
#  5   partner            7043 non-null   object
#  6   dependents         7043 non-null   object
#  7   online_security    7043 non-null   object
#  8   online_backup      7043 non-null   object
#  9   device_protection  7043 non-null   object
#  10  tech_support       7043 non-null   object
#  11  multiple_lines     7043 non-null   object
#  12  churn              7043 non-null   int32
#  13  duration           7043 non-null   int64
# dtypes: float64(1), int32(1), int64(2), object(10)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Предаварительный вывод
#
# **В этом разделе мы:**
#
# - **Исследовали категориальные признаки и пришли к следующим выводам:**
#
#     - Тип оплаты услуг (раз в год-два или ежемесячно) вряд ли влияет на отток клиентов. Преобладает помесячная оплата, и у нее меньшая доля оттока. Заплативших за 2 года обслуживания немного меньше, чем заплативших за год.
#     - Большинство ушедших клиентов получали электронные счета, но это вряд ли связано с причиной ухода. Скорее всего, это показатель вовлеченности клиентов в электронные способы оплаты услуг. Бумажные документы как правило предпочитают люди преклонного возраста.
#     - Гендер не влияет на отток клиентов.
#     - Большинство ушедших клиентов не имеют пенсионного статуса, чаще всего состоят в браке и не имеют детей.
#     - Тип подключения к интернету малозначительно влияет на уход клиента, так как ушедшие клиенты распределены пропорционально с оставшимися.
#     - Дополнительные услуги (блокировка опасных сайтов, облачное хранилище файлов, антивирус, выделенная линия технической поддержки, стриминговое телевидение, каталог фильмов, подключение телефона к нескольким линиям одновременно) также малозначительно влияют на уход клиента, из-за их низкой популярности среди пользователей.
#
# - **Исследовали числовые признаки и пришли к следующим выводам:**
#
#     - С начала 2014 года произошел резкий рост числа новых клиентов компании, вероятно, связанный с проведением промо-акций. После этого наблюдался плавный рост числа новых клиентов до середины 2019 года, примерно на уровне 75 клиентов в месяц. Затем произошло заметное увеличение ежемесячного прироста пользователей, примерно в 3 раза, что может свидетельствовать о проведении новых промо-акций в ответ на начавшийся отток клиентов.
#     - С 2015 года наблюдается рост числа ушедших пользователей компании. Пиковые значения по уходу пользователей приходятся на конец 2014 года, начало 4 квартала 2015 года, середину 2016 года, середину 4 квартала 2017 года, середину 4 квартала 2018 года и конец 4 квартала 2019 года.
#     - Количество дней пользования услугами находится в диапазоне от 0 до 2314 дней. Большинство клиентов уходит в диапазоне от 500 до 1500 дней. В среднем клиент пользуется услугами 898 дней, что примерно равно 2.5 годам.
#     - Уходящие клиенты обычно платят больше. Расходы за месяц у ушедших клиентов составляют в среднем около 100 у.е., в то время как у оставшихся клиентов этот показатель около 80 у.е. в месяц. Общие расходы у ушедших клиентов варьируются от 500 до 2000 у.е., а у оставшихся клиентов около 500 у.е.
#
# - **Признаки 'begin_date', 'end_date' и 'gender' были удалены как незначимые для машинного обучения.**
#
# - **Проверили корреляцию признаков:**
#
#     - Задали порог корреляции - 0.8. Признаки 'total_charges' и 'duration' показали самую высокую корреляцию - 0.85, поэтому удалили 'total_charges'.
#     - Признаки 'streaming_movies', 'streaming_tv' и 'internet_service', показавшие высокую корреляцию, были удалены, так как обнаружено, что их влияние на отток клиентов малозначительно.
#
# **Исследователький анализ данных завершен. Приступаем к подготовке данных к машинному обучению.**

# %% [markdown]
# ## Подготовка данных к машинному обучению

# %% [markdown]
# В этом разделе мы подготовим данные к машинному обучению согласно плану:
#
# - Посмотрим баланс классов
# - Определимся с метриками
# - Подготовим признаки
# - Разобьем на тренировочную и тестовую выборки

# %% [markdown]
# ### Посмотрим баланс классов целевого признака

# %%
plot_pie_chart(full_df, 'churn', figsize=(6, 6), labeldistance=1.1,
               pctdistance=0.85, fontsize=12, title='Баланс классов целевого признака')

# %% [markdown]
# Из графика мы видим наличие дисбаланса классов, поэтому критерием обучения моделей возьмем метрику AUC-ROC, которая не чуствительна к дисбалансу. Также будем использовать метод StratifiedKFold для кросс-валидации. Он полезен, когда у нас есть несбалансированный набор данных.
#
# Можем добавить к исследовательскому анализу, 15.6 % клиентов уходят из компании.
#
# Красота, да и только! С таким бубликом Ниединогоразрыва!)

# %% [markdown]
# ### Подготовим признаки

# %% [markdown]
# Поменяем тип данных в категориальном числовом признаке 'senior_citizen' на 'object'

# %%
full_df['senior_citizen'] = full_df['senior_citizen'].astype('object')
# Посмотрим на датафрейм
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   type               7043 non-null   object
#  1   paperless_billing  7043 non-null   object
#  2   payment_method     7043 non-null   object
#  3   monthly_charges    7043 non-null   float64
#  4   senior_citizen     7043 non-null   object
#  5   partner            7043 non-null   object
#  6   dependents         7043 non-null   object
#  7   online_security    7043 non-null   object
#  8   online_backup      7043 non-null   object
#  9   device_protection  7043 non-null   object
#  10  tech_support       7043 non-null   object
#  11  multiple_lines     7043 non-null   object
#  12  churn              7043 non-null   int32
#  13  duration           7043 non-null   int64
# dtypes: float64(1), int32(1), int64(1), object(11)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Разобьем данные на тренировочную и тестовую выборки

# %%
features_train, features_test, target_train, target_test = train_test_split(full_df.drop(
    'churn', axis=1), full_df['churn'], test_size=0.25, random_state=RANDOM_STATE, stratify=full_df['churn'])

# %% [markdown]
# Проверим разбиение

# %%
features_train, features_test, target_train, target_test = train_test_split(full_df.drop(
    'churn', axis=1), full_df['churn'], test_size=0.25, random_state=RANDOM_STATE, stratify=full_df['churn'])

#Проверим разделение:

print(f'Количество строк и столбцов в обучающей выборке: {features_train.shape}, '
      f'что составляет {round(len(features_train)/len(full_df)*100)}% от данных.')
print(f'Размер обучающего таргета: {target_train.shape}')
print(f'Количество строк и столбцов в тестовой выборке: {features_test.shape}, '
      f'что составляет {round(len(features_test)/len(full_df)*100)}% от данных.')
print(f'Размер тестового таргета: {target_test.shape}')
# Out:
# Количество строк и столбцов в обучающей выборке: (5282, 13), что составляет 75% от данных.
# Размер обучающего таргета: (5282,)
# Количество строк и столбцов в тестовой выборке: (1761, 13), что составляет 25% от данных.
# Размер тестового таргета: (1761,)

# %% [markdown]
# ### Предварительный вывод
#
# В этом разделе мы:
#
# - Посмотрели баланс классов целевого признака и выявили дисбаланс классов целевого признака.
# - Определились с метриками - ROC-AUC, как не чуствительную к дисбалансу классов целевого признака.
# - Определились с методом кросс-валидации - StratifiedKFold, как оптимальным для работы  с несбалансированным набором данных.
# - Поменяли тип данных в категориальном числовом признаке 'senior_citizen' на 'object'
# - Разбили данные на тренировочную и тестовую выборки.

# %% [markdown]
# ## Подбор и обучение моделей машинного обучения

# %% [markdown]
# **Будем обучать сдующие модели:**
#
# - По традиции запустим вперед линейную модель:
#     - **LogisticRegression**
#
# - 1 простую модель:
#     - **RandomForestClassifier**
#
# - 2 модели на основе градиентного бустинга:
#     - **CatBoostClassifier**
#     - **XGBClassifier**
#
# **Подберем лучшую модель с оптимальными гиперпараметрами и получим лучшую метрику ROC-AUC на кросс-валидации**

# %% [markdown]
# **Создадим таблицу с результатами обучения моделей:**

# %%
result_table = pd.DataFrame(columns=['Mодель', 'Гиперпараметры', 'ROC-AUC на трейне'])

# %% [markdown]
# #### LogisticRegression
#
# Logistic Regression - это линейный метод классификации, который использует логистическую функцию для прогнозирования вероятности нахождения объекта в одном из двух классов.

# %%
# %%time

# Создаем объект модели
model = LogisticRegression()

# Определяем параметры сетки для подбора гиперпараметров
param_grid = {
            'model': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear')],
            'model__C': np.logspace(-3, 3, 20),
            'model__penalty': ["l1", "l2"]
}

# Вызываем функцию test_model
lr_result, lr_model = test_model(features_train, target_train, LogisticRegression, param_grid)
# Выводим результаты
display(lr_result)
# Добавляем результаты в сводную таблицу
result_table = result_table.append(lr_result, ignore_index=True)
# Out:
# {'Mодель': 'LogisticRegression',
#  'Гиперпараметры': {'model__penalty': 'l2',
#   'model__C': 0.07847599703514611,
#   'model': LogisticRegression(C=0.07847599703514611, random_state=280823,
#                      solver='liblinear')},
#  'ROC-AUC на трейне': 0.75}
# Wall time: 4.93 s

# %% [markdown]
# #### Random Forest
# Random Forest - это ансамблевый метод машинного обучения, который строит множество деревьев решений и комбинирует их, чтобы получить более точный результат. Каждое дерево строится на случайном подмножестве признаков и объектов, что позволяет уменьшить переобучение.

# %%
# %%time
# Создаем объект модели
model = RandomForestClassifier()

# Определяем параметры сетки для подбора гиперпараметров
param_grid = {
        'model': [RandomForestClassifier(random_state=RANDOM_STATE)],
        'model__n_estimators': range(10, 101, 30),
        'model__max_depth': range(1, 6)
}

# Вызываем функцию test_model
rf_result, rf_model = test_model(features_train, target_train, RandomForestClassifier, param_grid)
# Выводим результаты
display(rf_result)
# Добавляем результаты в сводную таблицу
result_table = result_table.append(rf_result, ignore_index=True)
# Out:
# {'Mодель': 'RandomForestClassifier',
#  'Гиперпараметры': {'model__n_estimators': 100,
#   'model__max_depth': 5,
#   'model': RandomForestClassifier(max_depth=5, random_state=280823)},
#  'ROC-AUC на трейне': 0.8}
# Wall time: 6.03 s

# %% [markdown]
# #### CatBoostClassifier
# CatBoostClassifier - это классификатор на основе градиентного бустинга с категориальными признаками (categorical boosting), разработанный компанией Yandex. Он предназначен для решения задач классификации, используя градиентный бустинг на деревьях решений.

# %%
# %%time
# Создаем объект модели
model = CatBoostClassifier()

# Определяем параметры сетки для подбора гиперпараметров
param_grid = {
        'model': [CatBoostClassifier(loss_function='Logloss',
                                     eval_metric='AUC',
                                     task_type="CPU",
                                     verbose=False,
                                     random_seed=RANDOM_STATE)],
        'model__learning_rate': [0.01, 0.03, 0.001],
        'model__depth': range(1, 6)
    }

# Вызываем функцию test_model
cb_result, cb_model = test_model(features_train, target_train, CatBoostClassifier, param_grid)
# Выводим результаты
display(cb_result)
# Добавляем результаты в сводную таблицу
result_table = result_table.append(cb_result, ignore_index=True)
# Out:
# {'Mодель': 'CatBoostClassifier',
#  'Гиперпараметры': {'model__learning_rate': 0.03,
#   'model__depth': 5,
#   'model': <catboost.core.CatBoostClassifier at 0x117d67529d0>},
#  'ROC-AUC на трейне': 0.91}
# Wall time: 1min 28s

# %% [markdown]
# #### XGBClassifier
# XGBClassifier - это алгоритм градиентного бустинга, который использует ансамбль деревьев решений для классификации. Он использует регуляризацию для борьбы с переобучением и имеет высокую скорость работы.

# %%
# %%time
# Создаем объект модели
model = XGBClassifier()

# Определяем параметры сетки для подбора гиперпараметров
param_grid = {
        'model': [XGBClassifier(random_state=RANDOM_STATE)],
        'model__n_estimators': [100, 300, 500],
        'model__learning_rate': [0.01, 0.1, 0.5],
        'model__max_depth': [3, 5, 7],
        'model__subsample': [0.8, 0.9, 1.0],
        'model__colsample_bytree': [0.8, 0.9, 1.0],
        'model__gamma': [0, 1, 5]
    }

# Вызываем функцию test_model
xgbc_result, xgbc_model = test_model(features_train, target_train, XGBClassifier, param_grid)
# Выводим результаты
display(xgbc_result)
# Добавляем результаты в сводную таблицу
result_table = result_table.append(xgbc_result, ignore_index=True)
# Out:
# {'Mодель': 'XGBClassifier',
#  'Гиперпараметры': {'model__subsample': 1.0,
#   'model__n_estimators': 500,
#   'model__max_depth': 3,
#   'model__learning_rate': 0.1,
#   'model__gamma': 0,
#   'model__colsample_bytree': 1.0,
#   'model': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bynode=None,
#                 colsample_bytree=1.0, early_stopping_rounds=None,
#                 enable_categorical=False, eval_metric=None, feature_types=None,
#                 gamma=0, gpu_id=None, grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=0.1, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=3, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=500, n_jobs=None, num_parallel_tree=None,
# ...

# %% [markdown]
# #### Посмотим на сводную таблицу:

# %%
result_table.sort_values('ROC-AUC на трейне', ascending=False)
# Out:
#                    Mодель                                     Гиперпараметры  \
# 2      CatBoostClassifier  {'model__learning_rate': 0.03, 'model__depth':...
# 3           XGBClassifier  {'model__subsample': 1.0, 'model__n_estimators...
# 1  RandomForestClassifier  {'model__n_estimators': 100, 'model__max_depth...
# 0      LogisticRegression  {'model__penalty': 'l2', 'model__C': 0.0784759...
#
#    ROC-AUC на трейне
# 2               0.91
# 3               0.90
# 1               0.80
# 0               0.75

# %% [markdown]
# **Исходя из сводной таблицы, лучшей моделью можем признать CatBoostClassifier с метрикой ROC-AUC 0.91.**

# %% [markdown]
# ### Предварительный вывод
#
# - В этом разделе мы:
# - Выбрали 4 модели: одну линейную модель: **LogisticRegression**, 1 деревянную модель: **RandomForestClassifier** и 2 модели на основе градиентного бустинга: **CatBoostClassifier** и **XGBClassifier**.
# - Для подбора лучших гиперпараметров на кросс-валидации мы при помощи RandomizedSearchCV обработали каждую модель по отдельности и вывели результат в сводную таблицу. Лучшей моделью оказалась CatBoostClassifier с метрикой 0.91.
#
# **Приступим к тестированию лучшей модели.**

# %% [markdown]
# ## Тестирование лучшей модели

# %% [markdown]
# ### Протестируем и опишем лучшую модель

# %% [markdown]
# **Предскажем нашу модель на тестовой выборке. А также выведем  ROC-AUC и ассurасу, построим и опишем матрицу ошибок и ROC-кривую.**

# %%
evaluate_model(cb_model, features_test)
# Out:
# Модель: CatBoostClassifier
# ROC-AUC на тестовой выборке: 0.9116
# Точность (Accuracy) на тестовой выборке: 0.9103
# Резмер тестовой выборки: (1761,)

# %% [markdown]
# **Из построеной матрицы ошибок и ROC-кривой модели CatBoostClassifier построеной на тестовой выборке мы можем видеть:**
#
# - Резмер тестовой выборки - 1761
# - Модель верно предсказала оставшихся клиентов (класс 0) - 1474 раза
# - Модель ошиблась в предсказании оставшихся клиентов (класс 0) - 129 раза
# - Модель верно предсказала ушедших клиентов (класс 1) - 145 раза
# - Модель ошиблась в предсказании оставшихся клиентов (класс 1) - 12 раз
# - Таким образом, процент верных предсказаний для класса 0 составляет около 91.93%, в то время как процент ошибок составляет около 8.07%. Для класса 1 процент верных предсказаний составляет около 92.36%, а процент ошибок около 7,64%.
# - ROC -кривая визуализировала качество нашей модели. Высокое значение по оси Y говорит о большем количестве истинно положительных результатов по сравнению с ложно отрицательными.

# %% [markdown]
# ### Исследуем важность признаков модели

# %%
plot_feature_importance(cb_model)
# Out:
#                                           Важность признака
# Признак
# duration                                          56.862991
# monthly_charges                                   10.827905
# type_month-to-month                                5.581559
# type_two year                                      2.646755
# payment_method_mailed check                        2.433030
# multiple_lines_no                                  1.994035
# partner_no                                         1.774350
# partner_yes                                        1.626956
# multiple_lines_yes                                 1.568236
# payment_method_bank transfer (automatic)           1.426730
# online_backup_yes                                  1.126274
# payment_method_credit card (automatic)             1.023221
# online_backup_no                                   0.949760
# device_protection_no                               0.947295
# ...

# %% [markdown]
# Из графика и сводной таблицы мы можем увидеть, что самыми важными оказались признаки: duration(Количество дней обслуживания) с большим отывом лидирует, monthly_charges(расходы за месяц) и type_month-to-month(помесячный тип оплаты).

# %% [markdown]
# **Сортировка признаков по важности подтверждает исследовательский анализ данных, провенный выше. Также отметим, что модель предсказывает уход клиента с точностью 92.36%%. На основе полученых результатов можем сделать вывод, что наша модель (CatBoostClassifier) отлично подходит для поставленных задач.**

# %% [markdown]
# ### Предварительный вывод
# В этом разделе мы:
# - Проверили на тестовых данных модель XGBClassifier полученую при помощи корвеера:
#     - Модель показала метрики ROC-AUC - 0.9195, accuracy - 0.9154
#     - Провели анализ матрицы ошибок и ROC-кривой и обнаружили:
#         - Процент верных предсказаний для класса 0 составляет около 91.1%, а процент ошибок - примерно 8.9%. Для класса 1 процент верных ответов около 88.6%, а процент ошибок - около 11.4%.
#         - ROC -кривая показала высокое значение по оси Y, что говорит о большем количестве истинно положительных результатов по сравнению с ложно отрицательными.
#     - Исследовали важность признаков модели и обнаружили, что самыми важными оказались признаки: type_month-to-month(помесячный тип оплаты), type_two year(оплата за 2 года вперед) и multiple_lines_no(отсутвие подключения телефона к нескольким линиям одновременно).
# - Проверили на тестовых данных модель CatBoostClassifier полученую при помощи рукописной функции:
#     - Модель показала метрики ROC-AUC - 0.9116, accuracy - 0.9103
#     - Провели анализ матрицы ошибок и ROC-кривой и обнаружили:
#         - Процент верных предсказаний для класса 0 составляет около 91.1%, процент ошибок составляет около 8.9%. Для класса 1 процент предсказаний верных около 92.44%, а процент ошибок около 7,56%.
#         - ROC -кривая показала высокое значение по оси Y, что говорит о большем количестве истинно положительных результатов по сравнению с ложно отрицательными.
#     - Исследовали важность признаков модели и обнаружили, что самыми важными оказались признаки: tduration(Количество дней обслуживания) с большим отывом лидирует, monthly_charges(расходы за месяц) и type_month-to-month(помесячный тип оплаты).

# %% [markdown]
# ## Вывод

# %% [markdown]
# **В этом проекте мы, согласно плану реализовали следующие пункты:**
# 1. Провели первичный анализ данных:
#     - Загрузили и описали данные.
# 2. Провели предобработку данных:
#     - Объединили 4 датафрейма в один.
#     - Привели данные к нормальному виду.
#     - Обработали пропущенные значения.
#     - Выделили целевой признак для машинного обучения.
# 3. Провели исследовательский анализ данных:
#     - Исследовали признаки, выделили незначимые и малозначимые признаки для машинного обучения.
#     - Обнаружили связи и зависимости в данных, что помогло составить примерный портрет уходящего клиента - это человек не имеют пенсионного статуса, состояший в браке и не имеющий детей.
#     - Выявили, что среди оплаты преобладает помесячная.
#     - Дополнительные услуги пользуется низкой популярностью среди клиентов.
#     - Резкий рост клиентов скорее всего всязан с провдением промоакций.
#     - С 2015 года наблюдается рост количества ушедших пользователей компании.
#     - В среднем клиент пользуется услугами компании 2.5 года.
#     - Удалили признаки begin_date', 'end_date' и 'gender' как незначимые для машинного обучения.
#     - Проверили корреляцию признаков с порогом 0.8 и удалили признаки 'total_charges', 'streaming_movies', 'streaming_tv' и 'internet_service', превышавшие порог корреляции.
# 4. Подготовили данные к машинному обучению:
#     - Посмотрели баланс классов целевого признака и выявили дисбаланс классов целевого признака.
#     - Определились с метриками - ROC-AUC, как не чуствительную к дисбалансу классов целевого признака.
#     - Определились с методом кросс-валидации - StratifiedKFold, как оптимальным для работы с несбалансированным набором данных.
#     - Разбили данные на тренировочную и тестовую выборки
#     - Подготовили признаки применив StandardScaler к числовым признакам и OneHotEncoder к категориальным признакам.    .
# 5. Подборали и обучили модели машинного обучения:
#     - Выбрали 4 модели: LogisticRegression, RandomForestClassifier, CatBoostClassifier и XGBClassifier.
#     - Для подбора лучших гиперпараметров на кросс-валидации мы закодировали тренировочную выборку применив StandardScaler к числовым признакам и OneHotEncoder к категориальным признакам.
#     - При помощи RandomizedSearchCV, обработали каждую модель по отдельности и вывели результат в сводную таблицу. По результатам 2-го варианта лучшей моделью оказалась CatBoostClassifier с метрикой 0.9105.
# 6. Провели тестирование лучшей модели:
#     - Проверили на тестовых данных модель CatBoostClassifierи:
#         - Модель показала метрики ROC-AUC - 0.9116, accuracy - 0.9103
#         - Провели анализ матрицы ошибок и ROC-кривой и обнаружили:
#         - ROC -кривая показала высокое значение по оси Y
#         - Процент верных предсказаний для класса 0 составляет около 91.93%, процент ошибок составляет около 8.03%. Для класса 1 процент предсказаний верных около 92.44%, а процент ошибок около 7,56%.
#
# **На основе полученых результатов можем сделать вывод, что обученную модель (CatBoostClassifier) можно с успехом применять для поставленных задач.**

# %% [markdown]
# ## ОТЧЕТ

# %% [markdown]
# ### В ходе работы над проектом мы реализовывали следующий план:
#
# - Первичный анализ данных (Загрузим данные, посмотрим на них и опишем результат)
# - Предобработка данных (Объединим все данные в один датафрейм, приведем данные к нормальному виду, при наличии избавимся от пропусков, дубликатов и аномальных значений, ну и обязательно еще чтонибудь накопаем)
# - Исследовательский анализ данных (Исследуем данные на наличие связей, посмотрим корреляцию, определимся какие признаки оставим для машинного обучения)
# - Подготовка данных к машинному обучению (Разобьем на тренировочную и тестовую выборки, подготовим признаки, посмотрим баланс классов, определимся с метриками, и т.д.)
# - Подбор и обучение моделей машинного обучения (Выберем несколько методов ML, подберем лучшие гиперпараметры на кросс-валидации)
# - Тестирование лучшей модели (Протестируем модель показавшую лучшие метрики на тестовой выборке и сравним с константной моделью)
# - Вывод (Сделаем анализ лучшей модели, опишем важность признаков, построим матрицу ошибок. Также напишем вывод о проделаной работе)
#
# ***На начальном этапе в план была внесена корректировка: Выделен в отдельный пункт исследовательский анализ данных, который находился в пункте подготовка данных к машинному обучению.***

# %% [markdown]
# ### Проанализируем соответствие фактической работы нашему плану:
#
# - Данные успешно загружены и изучены
#
# - Предобработка прошла успешно: данные объединены, привдены в нормальный вид, устранены пропущеные значения.
#
# - Исследовательский анализ данных тоже прошел успешно: исследованы связи и зависимости в данных, исследованы числовые и категориальные признаки, выявлены малозначимые и незначимые признаки, посчитана корреляция и удалены незначимые признаки и превышающие корреляционный порог.
#
# - Подготовка данных к машинному обучению также прошла без нареканий: выявили дисбаланс классов целевого признака, определили метрикой - ROC-AUC, как не чуствительную к дисбалансу классов целевого признака. Определились с методом кросс-валидации - StratifiedKFold, разбили данные на тренировочную и тестовую выборки.
#
# - **С подбора и обучения моделей машинного обучения все пошло немного не по плану, но успешно:** выбрали алгоритмы машинного обучения, собрали пайплайн, пропустили через него все модели, получили хорошую метрику ROC-AUC для одного из алгоритмов. После было принято решение написать фунцию **test_model** для тренировки моделей по отдельности (для налядности)и внесения результата в таблицу В процессе тестирования функции , было обнаружено, что выбор лучшей модели и подбор ее гиперпараметров через пайплайн скопом и выбор лучшей модели и подбор ее гиперпараметров через функцию **test_model** выводят разный результат. Пайлайн возвращал модель XGBClassifier с метрикой ROC-AUC: 0.9083, а функция возращала модель CatBoostClassifier с метрикой 0.9105. Все параметры пайплайна, KFold, RandomizedSearchCV, и гиперапараметры моделей при этом идентичны параметрам в функции. **После консультации с тимлидом было принято решение остановться на втором варианте и вернуться к намеченому плану.**
#
# - Тестирование лучшей модели прошло успешно: проверили модель на тестовой выборке, построили и проанализировали ROC-кривую и матриц ошибок, проанализировали важность признаков. Наша модель показала хорошие метрики на тестовой выборке: ROC-AUC - 0.9116, accuracy - 0.9103, процент верных предсказаний для класса 1 (клиент ушел) составляет около 92.44%  и анализ важности признаков подтверждает исследоветельский анализ данных проведенный выше.

# %% [markdown]
# ### Проанализируем соответствие фактической работы нашему плану:
#
# - Данные успешно загружены и изучены
#
# - Предобработка прошла успешно: данные объединены, привдены в нормальный вид, устранены пропущеные значения.
#
# - Исследовательский анализ данных тоже прошел успешно: исследованы связи и зависимости в данных, исследованы числовые и категориальные признаки, выявлены малозначимые и незначимые признаки, посчитана корреляция и удалены незначимые признаки и превышающие корреляционный порог.
#
# - Подготовка данных к машинному обучению также прошла без нареканий: выявили дисбаланс классов целевого признака, определили метрикой - ROC-AUC, как не чуствительную к дисбалансу классов целевого признака. Определились с методом кросс-валидации - StratifiedKFold, разбили данные на тренировочную и тестовую выборки.
#
# - **С подбора и обучения моделей машинного обучения все пошло немного не по плану, но успешно:** выбрали алгоритмы машинного обучения, собрали пайплайн, пропустили через него все модели, получили хорошую метрику ROC-AUC для одного из алгоритмов. После было принято решение написать фунцию **test_model** для тренировки моделей по отдельности (для налядности)и внесения результата в таблицу. В процессе тестирования функции , было обнаружено, что выбор лучшей модели и подбор ее гиперпараметров через пайплайн скопом и выбор лучшей модели и подбор ее гиперпараметров через функцию **test_model** выводят разный результат. Пайлайн возвращал модель XGBClassifier с метрикой ROC-AUC: 0.9083, а функция возращала модель CatBoostClassifier с метрикой 0.9105. Все параметры пайплайна, KFold, RandomizedSearchCV, и гиперапараметры моделей при этом идентичны параметрам в функции.
#
# - **После консультации с тимлидом было принято решение остановться на втором варианте и вернуться к намеченому плану.**
#
# - Тестирование лучшей модели прошло успешно: проверили модель на тестовой выборке, построили и проанализировали ROC-кривую и матриц ошибок, проанализировали важность признаков. Наша модель показала хорошие метрики на тестовой выборке: ROC-AUC - 0.9116, accuracy - 0.9103, процент верных предсказаний для класса 1 (клиент ушел) составляет около 92.44%  и анализ важности признаков подтверждает исследоветельский анализ данных проведенный выше.

# %% [markdown]
# ### Анализ трудностей и путей их решения.
#
# - На этапе первичного анализа данных трудностей небыло - была использована немного модифицированная функция первичного анализа данных, которая выводит всю необходимую информацию о наборе данных. Далее было необходимо только описать увиденное.
#
# - На этапе предобработки данных столкнулись с проблемой: при попытке изменить тип данных в признаке 'totalcharges' были найдены пустые строки, что не давало привести столбец к типу float. Было принято решение использовать функцию to_numeric с параметром errors = 'coerce', чтобы вместо ошибки возвращалось значение Nan.
#
# - На этапе исследовательского анализа особых проблем небыло, разве только пришлось переписать несколько припасенных из прошлых проектов функций построения графиков и повозиться с построением графика распределения категориальных признаков, решалось это при помощи документации поисковых систем и методом проб и ошибок.
#
# - На этапе подготовки данных к машинному обучению, ошибочно закодировали признаки применив StandardScaler к числовым признакам и OneHotEncoder к категориальным признакам, до разбиения данных на тренировочную и тестовую выборки. После консультации с тимлидом перениесли кодирование в пайплайн.
#
# - Проблемы и способы их решения на этапе обучения модели описаны выше в анализе соответствия фактической работы плану.
#
# - На этапе тестирования лучшей модели проблем не было.

# %% [markdown]
# ### Лучшая модель подобранными с гиперпараметрами:
#
# В этом проекте мы обучали 4 модели: LogisticRegression, RandomForestClassifier, CatBoostClassifier и XGBClassifier.
# Результат обучения подбора гиперпараметров выведем в сводную таблицу:

# %%
result_table.sort_values('ROC-AUC на трейне', ascending=False)
# Out:
#                    Mодель                                     Гиперпараметры  \
# 2      CatBoostClassifier  {'model__learning_rate': 0.03, 'model__depth':...
# 3           XGBClassifier  {'model__subsample': 1.0, 'model__n_estimators...
# 1  RandomForestClassifier  {'model__n_estimators': 100, 'model__max_depth...
# 0      LogisticRegression  {'model__penalty': 'l2', 'model__C': 0.0784759...
#
#    ROC-AUC на трейне
# 2               0.91
# 3               0.90
# 1               0.80
# 0               0.75

# %% [markdown]
# **Лучшую метрику ROC-AUC на тестовой выборке показала модель CatBoostClassifier**

# %%
cb_result
# Out:
# {'Mодель': 'CatBoostClassifier',
#  'Гиперпараметры': {'model__learning_rate': 0.03,
#   'model__depth': 5,
#   'model': <catboost.core.CatBoostClassifier at 0x117d67529d0>},
#  'ROC-AUC на трейне': 0.91}

# %% [markdown]
# **На тренировочной выборке модель показала не менее отличный результат:**

# %%
evaluate_model(cb_model, features_test)
# Out:
# Модель: CatBoostClassifier
# ROC-AUC на тестовой выборке: 0.9116
# Точность (Accuracy) на тестовой выборке: 0.9103
# Резмер тестовой выборки: (1761,)

# %% [markdown]
# **Исследование матрицы ошибок и ROC-кривой модели CatBoostClassifier построеной на тестовой выборке показало:**
#
# - Резмер тестовой выборки - 1761
# - Модель верно предсказала оставшихся клиентов (класс 0) - 1474 раза
# - Модель ошиблась в предсказании оставшихся клиентов (класс 0) - 129 раза
# - Модель верно предсказала ушедших клиентов (класс 1) - 145 раза
# - Модель ошиблась в предсказании оставшихся клиентов (класс 1) - 12 раз
# - Таким образом, процент верных предсказаний для класса 0 составляет около 91.93%, процент ошибок составляет около 8.03%. Для класса 1 процент предсказаний верных около 92.44%, а процент ошибок около 7,56%.
# - ROC -кривая визуализировала качество нашей модели. Высокое значение по оси Y говорит о большем количестве истинно положительных результатов по сравнению с ложно отрицательными.
#
#
# - **Она показала на тестовой выборке метрику ROC-AUC - 0.9105, на тренировочной выборке ROC-AUC - 0.9116, accuracy - 0.9103**
#
# **Это говорит о высоком качестве модели.**
#
# 5. Признаки используемые для обучения модели и описание их предобработки:
# - Список категориальных признаков:
#     - 'type' — тип оплаты: раз в год-два или ежемесячно
#     - 'paperless_billing'— электронный расчётный лист
#     - 'payment_method' — тип платежа
#     - 'dependents' — есть ли у абонента дети
#     - 'online_security'— блокировка опасных сайтов
#     - 'online_backup'— облачное хранилище файлов для резервного копирования данных
#     - 'device_protection' — антивирус
#     - 'tech_support'— выделенная линия технической поддержки
#     - 'multiple_lines' — подключение телефона к нескольким линиям одновременно
#     - 'senior_citizen' — является ли абонент пенсионером
#
# - Список числовых признаков:
#     - 'monthly_charges' — расходы за месяц
#     - 'duration' — срок использования договора в днях
#
# - Целевой признак:
#     - 'churn' - ушел клиент или нет
#
# - Заголовки признако были приведены к snake_case, значения категориальных признаков были приведены к нижнему регистру.
#
# - Пропущенные значения в бинарных категориальных признаках 'online_security', 'online_backup', 'device_protection', 'tech_support' были заменены на 'no'
#
# - Пропущенные значения в признаке 'multiple_lines' были заменены на 'not_connected'
#
# - Были созданы признаки 'duration' и целевой признак 'churn'
#
# - Признаки были разделены на категориальные, которые были обработаны при помощи OneHotEncoder и числовые, которые были обработаны StandardScaler.
#
# **Распределение признаков по важности для обучения лучшей модели:**

# %%
plot_feature_importance(cb_model)
# Out:
#                                           Важность признака
# Признак
# duration                                          56.862991
# monthly_charges                                   10.827905
# type_month-to-month                                5.581559
# type_two year                                      2.646755
# payment_method_mailed check                        2.433030
# multiple_lines_no                                  1.994035
# partner_no                                         1.774350
# partner_yes                                        1.626956
# multiple_lines_yes                                 1.568236
# payment_method_bank transfer (automatic)           1.426730
# online_backup_yes                                  1.126274
# payment_method_credit card (automatic)             1.023221
# online_backup_no                                   0.949760
# device_protection_no                               0.947295
# ...

# %% [markdown]
# Самыми важными оказались признаки:
# - 'duration'(Количество дней обслуживания) с большим отрывом вырвался вперед.
# - 'monthly_charges'(расходы за месяц)
# - 'type_month-to-month'(помесячный тип оплаты).
#
# Сортировка признаков по важности подтверждает исследовательский анализ данных. Также отметим, что модель предсказывает уход клиента с точностью 92.44%.

# %% [markdown]
# **Отчет закончен.**
